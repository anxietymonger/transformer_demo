# %%
from datetime import datetime, timedelta

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import pandas as pd
import baostock as bs
import seaborn as sns

sns.set_theme()

# %%
torch.__version__
# Out:
# '2.0.0'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
def get_tradingdays(backdays):
    end = datetime.now()
    start = (end - timedelta(days=100)).strftime("%Y-%m-%d")
    rs = bs.query_trade_dates(start, end)
    data_list = []
    while (rs.error_code == "0") and rs.next():
        data_list.append(rs.get_row_data())
        
    result = pd.DataFrame(data_list, columns=rs.fields)
    result["is_trading_day"] = result["is_trading_day"].astype(int)
    
    return result[result["is_trading_day"] == True][-backdays:]["calendar_date"].tolist()

# %%
bs.login()
days = get_tradingdays(20)
bs.logout()
days
# Out:
# login success!
# logout success!
# ['2023-03-14',
#  '2023-03-15',
#  '2023-03-16',
#  '2023-03-17',
#  '2023-03-20',
#  '2023-03-21',
#  '2023-03-22',
#  '2023-03-23',
#  '2023-03-24',
#  '2023-03-27',
#  '2023-03-28',
#  '2023-03-29',
#  '2023-03-30',
#  '2023-03-31',
#  '2023-04-03',
#  '2023-04-04',
#  '2023-04-06',
#  '2023-04-07',
#  '2023-04-10',
#  '2023-04-11']

# %%
def get_zz500():
    rs = bs.query_zz500_stocks()
    data_list = []
    while (rs.error_code == "0") and rs.next():
        idx = rs.fields.index("code")
        data_list.append(rs.get_row_data()[idx])
    
    return data_list

# %%
def get_quote(code, start, end):
    rs = bs.query_history_k_data_plus(code, "open,high,low,close,volume", start_date=start, end_date=end, frequency="d", adjustflag="2")
    data_list = []
    while (rs.error_code == "0") and rs.next():
        data_list.append(rs.get_row_data())
    result = pd.DataFrame(data_list, columns=rs.fields).astype(np.float32)
    
    return result

# %%
bs.login()
zz500 = get_zz500()
bs.logout()
# Out:
# login success!
# logout success!

# %%
bs.login()
df = get_quote("sh.600036", "2000-01-01", "2023-04-09")
df.columns = ["Open", "High", "Low", "Close", "Volume"]
bs.logout()
# Out:
# login success!
# logout success!

# %%
sns.lineplot(df["Close"])
# Out:
# <Axes: ylabel='Close'>

# %%
len(df)
# Out:
# 5101

# %%
'''Calculate percentage change'''

df['Open'] = df['Open'].pct_change() # Create arithmetic returns column
df['High'] = df['High'].pct_change() # Create arithmetic returns column
df['Low'] = df['Low'].pct_change() # Create arithmetic returns column
df['Close'] = df['Close'].pct_change() # Create arithmetic returns column
df['Volume'] = df['Volume'].pct_change()

df.dropna(how='any', axis=0, inplace=True) # Drop all rows with NaN values
df['Volume'][df["Volume"] == np.inf] = 0

###############################################################################
'''Create indexes to split dataset'''

times = sorted(df.index.values)
last_10pct = sorted(df.index.values)[-int(0.1*len(times))] # Last 10% of series
last_20pct = sorted(df.index.values)[-int(0.2*len(times))] # Last 20% of series

###############################################################################
'''Normalize price columns'''
#
min_return = min(df[(df.index < last_20pct)][['Open', 'High', 'Low', 'Close']].min(axis=0))
max_return = max(df[(df.index < last_20pct)][['Open', 'High', 'Low', 'Close']].max(axis=0))

# Min-max normalize price columns (0-1 range)
df['Open'] = (df['Open'] - min_return) / (max_return - min_return)
df['High'] = (df['High'] - min_return) / (max_return - min_return)
df['Low'] = (df['Low'] - min_return) / (max_return - min_return)
df['Close'] = (df['Close'] - min_return) / (max_return - min_return)

###############################################################################
'''Normalize volume column'''

min_volume = df[(df.index < last_20pct)]['Volume'].min(axis=0)
max_volume = df[(df.index < last_20pct)]['Volume'].max(axis=0)

# Min-max normalize volume columns (0-1 range)
df['Volume'] = (df['Volume'] - min_volume) / (max_volume - min_volume)

###############################################################################
'''Create training, validation and test split'''

df_train = df[(df.index < last_20pct)]  # Training data are 80% of total data
df_val = df[(df.index >= last_20pct) & (df.index < last_10pct)]
df_test = df[(df.index >= last_10pct)]

# Convert pandas columns into arrays
train_data = df_train.values
val_data = df_val.values
test_data = df_test.values
print('Training data shape: {}'.format(train_data.shape))
print('Validation data shape: {}'.format(val_data.shape))
print('Test data shape: {}'.format(test_data.shape))

df_train.head()
# Out:
# Training data shape: (4042, 5)
# Validation data shape: (505, 5)
# Test data shape: (505, 5)
#        Open      High       Low     Close    Volume
# 1  0.439556  0.340741  0.357179  0.375743  0.011945
# 2  0.375743  0.387798  0.424653  0.369591  0.024418
# 3  0.363540  0.381782  0.390734  0.409032  0.067910
# 4  0.415169  0.381736  0.354015  0.339185  0.063469
# 5  0.327051  0.330265  0.328730  0.322808  0.097926

# %%
sns.lineplot(df["Volume"])
# Out:
# <Axes: ylabel='Volume'>

# %%
sns.lineplot(df["Close"])
# Out:
# <Axes: ylabel='Close'>

# %%
seq_len = 32

# %%
# Training data
X_train, y_train = [], []
for i in range(seq_len, len(train_data)):
  X_train.append(train_data[i-seq_len:i]) # Chunks of training data with a length of 128 df-rows
  y_train.append(train_data[:, 3][i]) #Value of 4th column (Close Price) of df-row 128+1
X_train, y_train = np.array(X_train), np.array(y_train)

###############################################################################

# Validation data
X_val, y_val = [], []
for i in range(seq_len, len(val_data)):
    X_val.append(val_data[i-seq_len:i])
    y_val.append(val_data[:, 3][i])
X_val, y_val = np.array(X_val), np.array(y_val)

###############################################################################

# Test data
X_test, y_test = [], []
for i in range(seq_len, len(test_data)):
    X_test.append(test_data[i-seq_len:i])
    y_test.append(test_data[:, 3][i])    
X_test, y_test = np.array(X_test), np.array(y_test)

print('Training set shape', X_train.shape, y_train.shape)
print('Validation set shape', X_val.shape, y_val.shape)
print('Testing set shape' ,X_test.shape, y_test.shape)
# Out:
# Training set shape (4010, 32, 5) (4010,)
# Validation set shape (473, 32, 5) (473,)
# Testing set shape (473, 32, 5) (473,)

# %%
class TimeVector(nn.Module):
    def __init__(self, seq_len):
        super().__init__()
        self.seq_len = int(seq_len)
        
        self.linear_w = nn.Parameter(torch.randn(self.seq_len))
        self.linear_b = nn.Parameter(torch.randn(self.seq_len))
        self.periodic_w = nn.Parameter(torch.randn(self.seq_len))
        self.periodic_b = nn.Parameter(torch.randn(self.seq_len))
        
    def forward(self, x):
        x = x[:,:4].mean(axis=-1)
        time_linear = self.linear_w * x + self.linear_b
        time_linear = torch.unsqueeze(time_linear, dim=-1)
        time_periodic = torch.sin(self.periodic_w * x + self.periodic_b)
        time_periodic = torch.unsqueeze(time_periodic, dim=-1)
        return torch.concat([time_linear, time_periodic], axis=-1)

# %%
class SingleAttention(nn.Module):
    def __init__(self, d_k, d_v):
        super().__init__()
        self.d_k = d_k
        self.d_v = d_v
        
        self.query = nn.Linear(7, self.d_k)
        self.key = nn.Linear(7, self.d_k)
        self.value = nn.Linear(7, self.d_v)
        
    def forward(self, x):
        q = self.query(x[0])
        k = self.key(x[1])
        
        out = torch.mm(q, k.mT)
        out = out / np.sqrt(self.d_k)
        out = torch.softmax(out, axis=-1)
        
        v = self.value(x[2])
        out = torch.mm(out, v)
        
        return out

# %%
class MultiAttention(nn.Module):
    def __init__(self, d_k, d_v, n_heads):
        super().__init__()
        self.d_k = d_k
        self.d_v = d_v
        self.n_heads = n_heads
        self.attn_heads = []
        
        for n in range(self.n_heads):
            self.attn_heads.append(SingleAttention(self.d_k, self.d_v))
            
        self.linear = nn.Linear(self.d_k * self.n_heads, 7)
        
    def forward(self, x):
        attns = [head(x) for head in self.attn_heads]
        concat_attns = torch.concat(attns, axis=-1)
        return self.linear(concat_attns)

# %%
class TransformerEncoder(nn.Module):
    def __init__(self, d_k, d_v, n_heads, ff_dim, dropout=0.1):
        super().__init__()
        self.d_k = d_k
        self.d_v = d_v
        self.ff_dim = ff_dim
        self.n_heads = n_heads
        self.attn_heads = []
        self.dropout_rate = dropout
        
        self.attn_multi = MultiAttention(self.d_k, self.d_v, self.n_heads)
        self.attn_dropout = nn.Dropout(self.dropout_rate)
        self.attn_normalize = nn.LayerNorm((seq_len, 7), eps=1e-6)
        
        self.ff_conv1d_1 = nn.Conv1d(seq_len, ff_dim, kernel_size=1)
        self.ff_conv1d_2 = nn.Conv1d(ff_dim, seq_len, kernel_size=1)
        self.ff_dropout = nn.Dropout(self.dropout_rate)
        self.ff_normalize = nn.LayerNorm((seq_len, 7), eps=1e-6)
        
    def forward(self, x):
        attn_layer = self.attn_multi(x)
        attn_layer = self.attn_dropout(attn_layer)
        attn_layer = self.attn_normalize(x[0] + attn_layer)
        
        ff_layer = self.ff_conv1d_1(attn_layer)
        ff_layer = F.relu(ff_layer)
        ff_layer = self.ff_conv1d_2(ff_layer)
        ff_layer = self.ff_dropout(ff_layer)
        ff_layer = self.ff_normalize(x[0] + ff_layer)
        
        return ff_layer

# %%
class TimeEmbeddingTransformer(nn.Module):
    def __init__(self, seq_len, d_k, d_v, n_heads, ff_dim, dropout=0.1):
        super().__init__()
        self.d_k = d_k
        self.d_v = d_v
        self.ff_dim = ff_dim
        self.n_heads = n_heads
        self.attn_heads = []
        self.dropout_rate = dropout
        
        self.time_embedding = TimeVector(seq_len)
        self.attn_layer1 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)
        self.attn_layer2 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)
        self.attn_layer3 = TransformerEncoder(d_k, d_v, n_heads, ff_dim)
        self.dropout1 = nn.Dropout(self.dropout_rate)
        self.linear1 = nn.Linear(seq_len, seq_len // 2)
        self.dropout2 = nn.Dropout(self.dropout_rate)
        self.linear2 = nn.Linear(seq_len // 2, 1)
        
    def forward(self, x):
        time_embedding = self.time_embedding(x)
        x = torch.concat([x, time_embedding], axis=-1)
        x = self.attn_layer1((x, x, x))
        x = self.attn_layer2((x, x, x))
        x = self.attn_layer3((x, x, x))
        x = x.mean(axis=-1)
        x = self.dropout1(x)
        x = self.linear1(x)
        x = F.relu(x)
        x = self.dropout2(x)
        x = self.linear2(x)
        
        return x

# %%
model = TimeEmbeddingTransformer(seq_len, 64, 64, 12, 64)

# %%
model
# Out:
# TimeEmbeddingTransformer(
#   (time_embedding): TimeVector()
#   (attn_layer1): TransformerEncoder(
#     (attn_multi): MultiAttention(
#       (linear): Linear(in_features=768, out_features=7, bias=True)
#     )
#     (attn_dropout): Dropout(p=0.1, inplace=False)
#     (attn_normalize): LayerNorm((32, 7), eps=1e-06, elementwise_affine=True)
#     (ff_conv1d_1): Conv1d(32, 64, kernel_size=(1,), stride=(1,))
#     (ff_conv1d_2): Conv1d(64, 32, kernel_size=(1,), stride=(1,))
#     (ff_dropout): Dropout(p=0.1, inplace=False)
#     (ff_normalize): LayerNorm((32, 7), eps=1e-06, elementwise_affine=True)
#   )
#   (attn_layer2): TransformerEncoder(
#     (attn_multi): MultiAttention(
#       (linear): Linear(in_features=768, out_features=7, bias=True)
#     )
#     (attn_dropout): Dropout(p=0.1, inplace=False)
#     (attn_normalize): LayerNorm((32, 7), eps=1e-06, elementwise_affine=True)
#     (ff_conv1d_1): Conv1d(32, 64, kernel_size=(1,), stride=(1,))
#     (ff_conv1d_2): Conv1d(64, 32, kernel_size=(1,), stride=(1,))
#     (ff_dropout): Dropout(p=0.1, inplace=False)
#     (ff_normalize): LayerNorm((32, 7), eps=1e-06, elementwise_affine=True)
#   )
#   (attn_layer3): TransformerEncoder(
#     (attn_multi): MultiAttention(
#       (linear): Linear(in_features=768, out_features=7, bias=True)
#     )
#     (attn_dropout): Dropout(p=0.1, inplace=False)
#     (attn_normalize): LayerNorm((32, 7), eps=1e-06, elementwise_affine=True)
#     (ff_conv1d_1): Conv1d(32, 64, kernel_size=(1,), stride=(1,))
#     (ff_conv1d_2): Conv1d(64, 32, kernel_size=(1,), stride=(1,))
#     (ff_dropout): Dropout(p=0.1, inplace=False)
#     (ff_normalize): LayerNorm((32, 7), eps=1e-06, elementwise_affine=True)
#   )
#   (dropout1): Dropout(p=0.1, inplace=False)
#   (linear1): Linear(in_features=32, out_features=16, bias=True)
#   (dropout2): Dropout(p=0.1, inplace=False)
#   (linear2): Linear(in_features=16, out_features=1, bias=True)
# )

# %%
loss_function = nn.MSELoss()
optimizer = optim.Adam(model.parameters())

# %%
for epoch in range(2):
    running_loss = 0
    for i, data in enumerate(X_train):
        optimizer.zero_grad()
        # data = torch.unsqueeze(torch.tensor(data), dim=0)
        y_pred = model(torch.tensor(data))
        loss = loss_function(y_pred, torch.tensor(y_train[i]))
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        
        if i % 500 == 0:
            print(f"{epoch=}, {i=}, {running_loss=:.5f}")
            running_loss = 0
# Out:
# epoch=0, i=0, loss=0.18074
# epoch=0, i=1, loss=0.14426
# epoch=0, i=2, loss=0.12371
# epoch=0, i=3, loss=0.02877
# epoch=0, i=4, loss=0.13124
# epoch=0, i=5, loss=0.04126
# epoch=0, i=6, loss=0.02033
# epoch=0, i=7, loss=0.03153
# epoch=0, i=8, loss=0.00729
# epoch=0, i=9, loss=0.00152
# epoch=0, i=10, loss=0.03808
# epoch=0, i=11, loss=0.00447
# epoch=0, i=12, loss=0.00584
# epoch=0, i=13, loss=0.00505
# epoch=0, i=14, loss=0.02178
# epoch=0, i=15, loss=0.01106
# epoch=0, i=16, loss=0.06837
# epoch=0, i=17, loss=0.01760
# epoch=0, i=18, loss=0.00875
# epoch=0, i=19, loss=0.00135
# epoch=0, i=20, loss=0.05104
# epoch=0, i=21, loss=0.00127
# epoch=0, i=22, loss=0.02928
# epoch=0, i=23, loss=0.02089
# epoch=0, i=24, loss=0.06281
# epoch=0, i=25, loss=0.02220
# epoch=0, i=26, loss=0.00270
# epoch=0, i=27, loss=0.00678
# epoch=0, i=28, loss=0.00799
# epoch=0, i=29, loss=0.00524
# epoch=0, i=30, loss=0.02048
# epoch=0, i=31, loss=0.00997
# epoch=0, i=32, loss=0.00076
# epoch=0, i=33, loss=0.00348
# epoch=0, i=34, loss=0.00002
# epoch=0, i=35, loss=0.00161
# epoch=0, i=36, loss=0.00283
# epoch=0, i=37, loss=0.00003
# epoch=0, i=38, loss=0.01219
# epoch=0, i=39, loss=0.00263
# epoch=0, i=40, loss=0.00009
# epoch=0, i=41, loss=0.00122
# epoch=0, i=42, loss=0.05145
# epoch=0, i=43, loss=0.01394
# epoch=0, i=44, loss=0.00041
# epoch=0, i=45, loss=0.00336
# epoch=0, i=46, loss=0.00076
# epoch=0, i=47, loss=0.00174
# epoch=0, i=48, loss=0.00060
# epoch=0, i=49, loss=0.00315
# epoch=0, i=50, loss=0.00067
# epoch=0, i=51, loss=0.00001
# epoch=0, i=52, loss=0.00043
# epoch=0, i=53, loss=0.01280
# epoch=0, i=54, loss=0.00056
# epoch=0, i=55, loss=0.00118
# epoch=0, i=56, loss=0.04493
# epoch=0, i=57, loss=0.00761
# epoch=0, i=58, loss=0.00001
# epoch=0, i=59, loss=0.01329
# epoch=0, i=60, loss=0.00075
# epoch=0, i=61, loss=0.00024
# epoch=0, i=62, loss=0.00006
# epoch=0, i=63, loss=0.00005
# epoch=0, i=64, loss=0.00206
# epoch=0, i=65, loss=0.00342
# epoch=0, i=66, loss=0.00186
# epoch=0, i=67, loss=0.00792
# epoch=0, i=68, loss=0.00272
# epoch=0, i=69, loss=0.00323
# epoch=0, i=70, loss=0.01227
# epoch=0, i=71, loss=0.00386
# epoch=0, i=72, loss=0.00051
# epoch=0, i=73, loss=0.00081
# epoch=0, i=74, loss=0.00005
# epoch=0, i=75, loss=0.00003
# epoch=0, i=76, loss=0.00959
# epoch=0, i=77, loss=0.00684
# epoch=0, i=78, loss=0.00289
# epoch=0, i=79, loss=0.00724
# epoch=0, i=80, loss=0.00036
# epoch=0, i=81, loss=0.00156
# epoch=0, i=82, loss=0.00235
# epoch=0, i=83, loss=0.00202
# epoch=0, i=84, loss=0.00002
# epoch=0, i=85, loss=0.00163
# epoch=0, i=86, loss=0.00065
# epoch=0, i=87, loss=0.00582
# epoch=0, i=88, loss=0.00174
# epoch=0, i=89, loss=0.00100
# epoch=0, i=90, loss=0.00031
# epoch=0, i=91, loss=0.00205
# epoch=0, i=92, loss=0.00100
# epoch=0, i=93, loss=0.00360
# epoch=0, i=94, loss=0.02336
# epoch=0, i=95, loss=0.00002
# epoch=0, i=96, loss=0.00032
# epoch=0, i=97, loss=0.00213
# epoch=0, i=98, loss=0.00003
# epoch=0, i=99, loss=0.00004
# epoch=0, i=100, loss=0.00023
# epoch=0, i=101, loss=0.00023
# epoch=0, i=102, loss=0.00741
# epoch=0, i=103, loss=0.00256
# epoch=0, i=104, loss=0.00034
# epoch=0, i=105, loss=0.01682
# epoch=0, i=106, loss=0.00634
# epoch=0, i=107, loss=0.00025
# epoch=0, i=108, loss=0.00831
# epoch=0, i=109, loss=0.01062
# epoch=0, i=110, loss=0.00078
# epoch=0, i=111, loss=0.00206
# epoch=0, i=112, loss=0.00338
# epoch=0, i=113, loss=0.00625
# epoch=0, i=114, loss=0.00499
# epoch=0, i=115, loss=0.01037
# epoch=0, i=116, loss=0.02556
# epoch=0, i=117, loss=0.00379
# epoch=0, i=118, loss=0.00403
# epoch=0, i=119, loss=0.00001
# epoch=0, i=120, loss=0.02375
# epoch=0, i=121, loss=0.00091
# epoch=0, i=122, loss=0.00243
# epoch=0, i=123, loss=0.00633
# epoch=0, i=124, loss=0.00158
# epoch=0, i=125, loss=0.01100
# epoch=0, i=126, loss=0.00007
# epoch=0, i=127, loss=0.00007
# epoch=0, i=128, loss=0.00695
# epoch=0, i=129, loss=0.00056
# epoch=0, i=130, loss=0.00726
# epoch=0, i=131, loss=0.00009
# epoch=0, i=132, loss=0.00017
# epoch=0, i=133, loss=0.00003
# epoch=0, i=134, loss=0.00038
# epoch=0, i=135, loss=0.00779
# epoch=0, i=136, loss=0.00114
# epoch=0, i=137, loss=0.00079
# epoch=0, i=138, loss=0.00277
# epoch=0, i=139, loss=0.00148
# epoch=0, i=140, loss=0.00577
# epoch=0, i=141, loss=0.00058
# epoch=0, i=142, loss=0.00244
# epoch=0, i=143, loss=0.00004
# epoch=0, i=144, loss=0.00267
# epoch=0, i=145, loss=0.01200
# epoch=0, i=146, loss=0.00012
# epoch=0, i=147, loss=0.00177
# epoch=0, i=148, loss=0.00617
# epoch=0, i=149, loss=0.00029
# epoch=0, i=150, loss=0.00387
# epoch=0, i=151, loss=0.01906
# epoch=0, i=152, loss=0.02398
# epoch=0, i=153, loss=0.00367
# epoch=0, i=154, loss=0.00270
# epoch=0, i=155, loss=0.12336
# epoch=0, i=156, loss=0.02005
# epoch=0, i=157, loss=0.00324
# epoch=0, i=158, loss=0.00611
# epoch=0, i=159, loss=0.00573
# epoch=0, i=160, loss=0.00625
# epoch=0, i=161, loss=0.00071
# epoch=0, i=162, loss=0.00045
# epoch=0, i=163, loss=0.00010
# epoch=0, i=164, loss=0.00501
# epoch=0, i=165, loss=0.00045
# epoch=0, i=166, loss=0.00000
# epoch=0, i=167, loss=0.02160
# epoch=0, i=168, loss=0.01048
# epoch=0, i=169, loss=0.00029
# epoch=0, i=170, loss=0.00492
# epoch=0, i=171, loss=0.00601
# epoch=0, i=172, loss=0.01407
# epoch=0, i=173, loss=0.00480
# epoch=0, i=174, loss=0.00080
# epoch=0, i=175, loss=0.00012
# epoch=0, i=176, loss=0.00072
# epoch=0, i=177, loss=0.00236
# epoch=0, i=178, loss=0.00144
# epoch=0, i=179, loss=0.00432
# epoch=0, i=180, loss=0.00888
# epoch=0, i=181, loss=0.01211
# epoch=0, i=182, loss=0.00014
# epoch=0, i=183, loss=0.00037
# epoch=0, i=184, loss=0.00039
# epoch=0, i=185, loss=0.00373
# epoch=0, i=186, loss=0.00141
# epoch=0, i=187, loss=0.00163
# epoch=0, i=188, loss=0.00181
# epoch=0, i=189, loss=0.00063
# epoch=0, i=190, loss=0.00000
# epoch=0, i=191, loss=0.00252
# epoch=0, i=192, loss=0.00113
# epoch=0, i=193, loss=0.00781
# epoch=0, i=194, loss=0.07884
# epoch=0, i=195, loss=0.00001
# epoch=0, i=196, loss=0.00209
# epoch=0, i=197, loss=0.00167
# epoch=0, i=198, loss=0.00115
# epoch=0, i=199, loss=0.00062
# epoch=0, i=200, loss=0.01448
# epoch=0, i=201, loss=0.00188
# epoch=0, i=202, loss=0.00112
# epoch=0, i=203, loss=0.01246
# epoch=0, i=204, loss=0.00017
# epoch=0, i=205, loss=0.00503
# epoch=0, i=206, loss=0.00007
# epoch=0, i=207, loss=0.00714
# epoch=0, i=208, loss=0.00259
# epoch=0, i=209, loss=0.05560
# epoch=0, i=210, loss=0.00317
# epoch=0, i=211, loss=0.00132
# epoch=0, i=212, loss=0.00002
# epoch=0, i=213, loss=0.00057
# epoch=0, i=214, loss=0.00763
# epoch=0, i=215, loss=0.03591
# epoch=0, i=216, loss=0.01571
# epoch=0, i=217, loss=0.03755
# epoch=0, i=218, loss=0.00027
# epoch=0, i=219, loss=0.00342
# epoch=0, i=220, loss=0.01497
# epoch=0, i=221, loss=0.00044
# epoch=0, i=222, loss=0.11829
# epoch=0, i=223, loss=0.00269
# epoch=0, i=224, loss=0.00530
# epoch=0, i=225, loss=0.01258
# epoch=0, i=226, loss=0.00000
# epoch=0, i=227, loss=0.00090
# epoch=0, i=228, loss=0.00016
# epoch=0, i=229, loss=0.00110
# epoch=0, i=230, loss=0.00974
# epoch=0, i=231, loss=0.00511
# epoch=0, i=232, loss=0.00054
# epoch=0, i=233, loss=0.00515
# epoch=0, i=234, loss=0.00006
# epoch=0, i=235, loss=0.00000
# epoch=0, i=236, loss=0.00004
# epoch=0, i=237, loss=0.01283
# epoch=0, i=238, loss=0.00014
# epoch=0, i=239, loss=0.00522
# epoch=0, i=240, loss=0.00192
# epoch=0, i=241, loss=0.00584
# epoch=0, i=242, loss=0.00008
# epoch=0, i=243, loss=0.00779
# epoch=0, i=244, loss=0.00003
# epoch=0, i=245, loss=0.01109
# epoch=0, i=246, loss=0.00002
# epoch=0, i=247, loss=0.01210
# epoch=0, i=248, loss=0.00059
# epoch=0, i=249, loss=0.00004
# epoch=0, i=250, loss=0.00653
# epoch=0, i=251, loss=0.00000
# epoch=0, i=252, loss=0.00718
# epoch=0, i=253, loss=0.00004
# epoch=0, i=254, loss=0.00018
# epoch=0, i=255, loss=0.00040
# epoch=0, i=256, loss=0.00794
# epoch=0, i=257, loss=0.00211
# epoch=0, i=258, loss=0.00954
# epoch=0, i=259, loss=0.00026
# epoch=0, i=260, loss=0.00115
# epoch=0, i=261, loss=0.00036
# epoch=0, i=262, loss=0.04140
# epoch=0, i=263, loss=0.00021
# epoch=0, i=264, loss=0.00245
# epoch=0, i=265, loss=0.00162
# epoch=0, i=266, loss=0.00857
# epoch=0, i=267, loss=0.00208
# epoch=0, i=268, loss=0.00119
# epoch=0, i=269, loss=0.00315
# epoch=0, i=270, loss=0.00386
# epoch=0, i=271, loss=0.00023
# epoch=0, i=272, loss=0.00433
# epoch=0, i=273, loss=0.00001
# epoch=0, i=274, loss=0.00688
# epoch=0, i=275, loss=0.00004
# epoch=0, i=276, loss=0.01861
# epoch=0, i=277, loss=0.00213
# epoch=0, i=278, loss=0.00022
# epoch=0, i=279, loss=0.00036
# epoch=0, i=280, loss=0.00182
# epoch=0, i=281, loss=0.00857
# epoch=0, i=282, loss=0.00020
# epoch=0, i=283, loss=0.00644
# epoch=0, i=284, loss=0.00102
# epoch=0, i=285, loss=0.00291
# epoch=0, i=286, loss=0.00272
# epoch=0, i=287, loss=0.00525
# epoch=0, i=288, loss=0.00113
# epoch=0, i=289, loss=0.00287
# epoch=0, i=290, loss=0.00318
# epoch=0, i=291, loss=0.02321
# epoch=0, i=292, loss=0.00010
# epoch=0, i=293, loss=0.00120
# epoch=0, i=294, loss=0.00286
# epoch=0, i=295, loss=0.00201
# epoch=0, i=296, loss=0.00000
# epoch=0, i=297, loss=0.00204
# epoch=0, i=298, loss=0.00032
# epoch=0, i=299, loss=0.00323
# epoch=0, i=300, loss=0.00008
# epoch=0, i=301, loss=0.00051
# epoch=0, i=302, loss=0.00563
# epoch=0, i=303, loss=0.00633
# epoch=0, i=304, loss=0.00732
# epoch=0, i=305, loss=0.06700
# epoch=0, i=306, loss=0.00501
# epoch=0, i=307, loss=0.00435
# epoch=0, i=308, loss=0.00001
# epoch=0, i=309, loss=0.00751
# epoch=0, i=310, loss=0.00020
# epoch=0, i=311, loss=0.00259
# epoch=0, i=312, loss=0.00825
# epoch=0, i=313, loss=0.00232
# epoch=0, i=314, loss=0.00453
# epoch=0, i=315, loss=0.01196
# epoch=0, i=316, loss=0.00354
# epoch=0, i=317, loss=0.00749
# epoch=0, i=318, loss=0.00625
# epoch=0, i=319, loss=0.00160
# epoch=0, i=320, loss=0.00198
# epoch=0, i=321, loss=0.03736
# epoch=0, i=322, loss=0.00154
# epoch=0, i=323, loss=0.00015
# epoch=0, i=324, loss=0.00214
# epoch=0, i=325, loss=0.00302
# epoch=0, i=326, loss=0.00948
# epoch=0, i=327, loss=0.02685
# epoch=0, i=328, loss=0.00084
# epoch=0, i=329, loss=0.01087
# epoch=0, i=330, loss=0.00947
# epoch=0, i=331, loss=0.00045
# epoch=0, i=332, loss=0.00062
# epoch=0, i=333, loss=0.01279
# epoch=0, i=334, loss=0.00184
# epoch=0, i=335, loss=0.00468
# epoch=0, i=336, loss=0.00502
# epoch=0, i=337, loss=0.01114
# epoch=0, i=338, loss=0.00155
# epoch=0, i=339, loss=0.00191
# epoch=0, i=340, loss=0.00079
# epoch=0, i=341, loss=0.01066
# epoch=0, i=342, loss=0.02468
# epoch=0, i=343, loss=0.00957
# epoch=0, i=344, loss=0.00002
# epoch=0, i=345, loss=0.00048
# epoch=0, i=346, loss=0.03586
# epoch=0, i=347, loss=0.00018
# epoch=0, i=348, loss=0.00837
# epoch=0, i=349, loss=0.00724
# epoch=0, i=350, loss=0.01151
# epoch=0, i=351, loss=0.00528
# epoch=0, i=352, loss=0.01475
# epoch=0, i=353, loss=0.00292
# epoch=0, i=354, loss=0.00007
# epoch=0, i=355, loss=0.00601
# epoch=0, i=356, loss=0.00025
# epoch=0, i=357, loss=0.01189
# epoch=0, i=358, loss=0.00313
# epoch=0, i=359, loss=0.00140
# epoch=0, i=360, loss=0.01393
# epoch=0, i=361, loss=0.00089
# epoch=0, i=362, loss=0.00177
# epoch=0, i=363, loss=0.00616
# epoch=0, i=364, loss=0.00036
# epoch=0, i=365, loss=0.06932
# epoch=0, i=366, loss=0.00560
# epoch=0, i=367, loss=0.00000
# epoch=0, i=368, loss=0.01958
# epoch=0, i=369, loss=0.00003
# epoch=0, i=370, loss=0.00209
# epoch=0, i=371, loss=0.00489
# epoch=0, i=372, loss=0.03475
# epoch=0, i=373, loss=0.02220
# epoch=0, i=374, loss=0.00034
# epoch=0, i=375, loss=0.01090
# epoch=0, i=376, loss=0.00025
# epoch=0, i=377, loss=0.01002
# epoch=0, i=378, loss=0.00165
# epoch=0, i=379, loss=0.00116
# epoch=0, i=380, loss=0.00172
# epoch=0, i=381, loss=0.01263
# epoch=0, i=382, loss=0.00256
# epoch=0, i=383, loss=0.00656
# epoch=0, i=384, loss=0.00308
# epoch=0, i=385, loss=0.00083
# epoch=0, i=386, loss=0.00530
# epoch=0, i=387, loss=0.00167
# epoch=0, i=388, loss=0.00076
# epoch=0, i=389, loss=0.00967
# epoch=0, i=390, loss=0.01897
# epoch=0, i=391, loss=0.00188
# epoch=0, i=392, loss=0.04458
# epoch=0, i=393, loss=0.01021
# epoch=0, i=394, loss=0.01413
# epoch=0, i=395, loss=0.00491
# epoch=0, i=396, loss=0.00486
# epoch=0, i=397, loss=0.00316
# epoch=0, i=398, loss=0.00054
# epoch=0, i=399, loss=0.00179
# epoch=0, i=400, loss=0.00282
# epoch=0, i=401, loss=0.01021
# epoch=0, i=402, loss=0.01994
# epoch=0, i=403, loss=0.00474
# epoch=0, i=404, loss=0.00034
# epoch=0, i=405, loss=0.00081
# epoch=0, i=406, loss=0.00164
# epoch=0, i=407, loss=0.00428
# epoch=0, i=408, loss=0.01185
# epoch=0, i=409, loss=0.00152
# epoch=0, i=410, loss=0.00204
# epoch=0, i=411, loss=0.01584
# epoch=0, i=412, loss=0.00010
# epoch=0, i=413, loss=0.00054
# epoch=0, i=414, loss=0.00251
# epoch=0, i=415, loss=0.00322
# epoch=0, i=416, loss=0.02347
# epoch=0, i=417, loss=0.00086
# epoch=0, i=418, loss=0.00677
# epoch=0, i=419, loss=0.00395
# epoch=0, i=420, loss=0.00069
# epoch=0, i=421, loss=0.00432
# epoch=0, i=422, loss=0.00018
# epoch=0, i=423, loss=0.00038
# epoch=0, i=424, loss=0.00004
# epoch=0, i=425, loss=0.00033
# epoch=0, i=426, loss=0.00000
# epoch=0, i=427, loss=0.00006
# epoch=0, i=428, loss=0.01252
# epoch=0, i=429, loss=0.00000
# epoch=0, i=430, loss=0.00279
# epoch=0, i=431, loss=0.03447
# epoch=0, i=432, loss=0.00058
# epoch=0, i=433, loss=0.01657
# epoch=0, i=434, loss=0.00029
# epoch=0, i=435, loss=0.00694
# epoch=0, i=436, loss=0.00009
# epoch=0, i=437, loss=0.00812
# epoch=0, i=438, loss=0.00120
# epoch=0, i=439, loss=0.00292
# epoch=0, i=440, loss=0.00004
# epoch=0, i=441, loss=0.00487
# epoch=0, i=442, loss=0.00320
# epoch=0, i=443, loss=0.00259
# epoch=0, i=444, loss=0.00186
# epoch=0, i=445, loss=0.00076
# epoch=0, i=446, loss=0.00131
# epoch=0, i=447, loss=0.00203
# epoch=0, i=448, loss=0.00621
# epoch=0, i=449, loss=0.00370
# epoch=0, i=450, loss=0.00060
# epoch=0, i=451, loss=0.00075
# epoch=0, i=452, loss=0.00043
# epoch=0, i=453, loss=0.00393
# epoch=0, i=454, loss=0.00004
# epoch=0, i=455, loss=0.00489
# epoch=0, i=456, loss=0.00037
# epoch=0, i=457, loss=0.00640
# epoch=0, i=458, loss=0.00116
# epoch=0, i=459, loss=0.00112
# epoch=0, i=460, loss=0.00122
# epoch=0, i=461, loss=0.00243
# epoch=0, i=462, loss=0.00188
# epoch=0, i=463, loss=0.00395
# epoch=0, i=464, loss=0.00857
# epoch=0, i=465, loss=0.00114
# epoch=0, i=466, loss=0.00003
# epoch=0, i=467, loss=0.00978
# epoch=0, i=468, loss=0.01806
# epoch=0, i=469, loss=0.00592
# epoch=0, i=470, loss=0.00024
# epoch=0, i=471, loss=0.01606
# epoch=0, i=472, loss=0.00562
# epoch=0, i=473, loss=0.00222
# epoch=0, i=474, loss=0.00002
# epoch=0, i=475, loss=0.00001
# epoch=0, i=476, loss=0.00119
# epoch=0, i=477, loss=0.00676
# epoch=0, i=478, loss=0.00271
# epoch=0, i=479, loss=0.00161
# epoch=0, i=480, loss=0.00016
# epoch=0, i=481, loss=0.00007
# epoch=0, i=482, loss=0.00737
# epoch=0, i=483, loss=0.00209
# epoch=0, i=484, loss=0.01525
# epoch=0, i=485, loss=0.00114
# epoch=0, i=486, loss=0.00961
# epoch=0, i=487, loss=0.00209
# epoch=0, i=488, loss=0.00109
# epoch=0, i=489, loss=0.00453
# epoch=0, i=490, loss=0.00029
# epoch=0, i=491, loss=0.00000
# epoch=0, i=492, loss=0.00865
# epoch=0, i=493, loss=0.00004
# epoch=0, i=494, loss=0.00087
# epoch=0, i=495, loss=0.00176
# epoch=0, i=496, loss=0.00732
# epoch=0, i=497, loss=0.00228
# epoch=0, i=498, loss=0.00067
# epoch=0, i=499, loss=0.01816
# epoch=0, i=500, loss=0.00156
# epoch=0, i=501, loss=0.00010
# epoch=0, i=502, loss=0.00954
# epoch=0, i=503, loss=0.00001
# epoch=0, i=504, loss=0.01275
# epoch=0, i=505, loss=0.00212
# epoch=0, i=506, loss=0.00210
# epoch=0, i=507, loss=0.00026
# epoch=0, i=508, loss=0.00248
# epoch=0, i=509, loss=0.00393
# epoch=0, i=510, loss=0.00482
# epoch=0, i=511, loss=0.00801
# epoch=0, i=512, loss=0.00002
# epoch=0, i=513, loss=0.00016
# epoch=0, i=514, loss=0.00819
# epoch=0, i=515, loss=0.00263
# epoch=0, i=516, loss=0.00085
# epoch=0, i=517, loss=0.00447
# epoch=0, i=518, loss=0.00035
# epoch=0, i=519, loss=0.00742
# epoch=0, i=520, loss=0.00037
# epoch=0, i=521, loss=0.00274
# epoch=0, i=522, loss=0.00538
# epoch=0, i=523, loss=0.00056
# epoch=0, i=524, loss=0.00141
# epoch=0, i=525, loss=0.00173
# epoch=0, i=526, loss=0.00001
# epoch=0, i=527, loss=0.00736
# epoch=0, i=528, loss=0.00510
# epoch=0, i=529, loss=0.00409
# epoch=0, i=530, loss=0.00324
# epoch=0, i=531, loss=0.03601
# epoch=0, i=532, loss=0.00011
# epoch=0, i=533, loss=0.00018
# epoch=0, i=534, loss=0.00065
# epoch=0, i=535, loss=0.00123
# epoch=0, i=536, loss=0.00119
# epoch=0, i=537, loss=0.00082
# epoch=0, i=538, loss=0.00011
# epoch=0, i=539, loss=0.00081
# epoch=0, i=540, loss=0.00131
# epoch=0, i=541, loss=0.00500
# epoch=0, i=542, loss=0.00319
# epoch=0, i=543, loss=0.00010
# epoch=0, i=544, loss=0.00026
# epoch=0, i=545, loss=0.00463
# epoch=0, i=546, loss=0.00076
# epoch=0, i=547, loss=0.00406
# epoch=0, i=548, loss=0.01019
# epoch=0, i=549, loss=0.00321
# epoch=0, i=550, loss=0.00004
# epoch=0, i=551, loss=0.00294
# epoch=0, i=552, loss=0.00122
# epoch=0, i=553, loss=0.00039
# epoch=0, i=554, loss=0.00009
# epoch=0, i=555, loss=0.00092
# epoch=0, i=556, loss=0.00254
# epoch=0, i=557, loss=0.00377
# epoch=0, i=558, loss=0.01196
# epoch=0, i=559, loss=0.00289
# epoch=0, i=560, loss=0.00695
# epoch=0, i=561, loss=0.02888
# epoch=0, i=562, loss=0.00257
# epoch=0, i=563, loss=0.01288
# epoch=0, i=564, loss=0.04170
# epoch=0, i=565, loss=0.01286
# epoch=0, i=566, loss=0.00552
# epoch=0, i=567, loss=0.00519
# epoch=0, i=568, loss=0.00582
# epoch=0, i=569, loss=0.00010
# epoch=0, i=570, loss=0.00151
# epoch=0, i=571, loss=0.00784
# epoch=0, i=572, loss=0.00777
# epoch=0, i=573, loss=0.00020
# epoch=0, i=574, loss=0.00791
# epoch=0, i=575, loss=0.00043
# epoch=0, i=576, loss=0.00018
# epoch=0, i=577, loss=0.00013
# epoch=0, i=578, loss=0.00052
# epoch=0, i=579, loss=0.02292
# epoch=0, i=580, loss=0.01083
# epoch=0, i=581, loss=0.00070
# epoch=0, i=582, loss=0.01355
# epoch=0, i=583, loss=0.00618
# epoch=0, i=584, loss=0.00004
# epoch=0, i=585, loss=0.00175
# epoch=0, i=586, loss=0.00096
# epoch=0, i=587, loss=0.00016
# epoch=0, i=588, loss=0.00920
# epoch=0, i=589, loss=0.00084
# epoch=0, i=590, loss=0.02328
# epoch=0, i=591, loss=0.00009
# epoch=0, i=592, loss=0.00022
# epoch=0, i=593, loss=0.01747
# epoch=0, i=594, loss=0.00367
# epoch=0, i=595, loss=0.00408
# epoch=0, i=596, loss=0.00411
# epoch=0, i=597, loss=0.00256
# epoch=0, i=598, loss=0.00129
# epoch=0, i=599, loss=0.00043
# epoch=0, i=600, loss=0.00221
# epoch=0, i=601, loss=0.00114
# epoch=0, i=602, loss=0.00120
# epoch=0, i=603, loss=0.00119
# epoch=0, i=604, loss=0.00074
# epoch=0, i=605, loss=0.00272
# epoch=0, i=606, loss=0.00126
# epoch=0, i=607, loss=0.00140
# epoch=0, i=608, loss=0.00026
# epoch=0, i=609, loss=0.00635
# epoch=0, i=610, loss=0.00024
# epoch=0, i=611, loss=0.00120
# epoch=0, i=612, loss=0.00302
# epoch=0, i=613, loss=0.00586
# epoch=0, i=614, loss=0.00308
# epoch=0, i=615, loss=0.00044
# epoch=0, i=616, loss=0.00013
# epoch=0, i=617, loss=0.00058
# epoch=0, i=618, loss=0.00073
# epoch=0, i=619, loss=0.00013
# epoch=0, i=620, loss=0.00052
# epoch=0, i=621, loss=0.00435
# epoch=0, i=622, loss=0.00177
# epoch=0, i=623, loss=0.01003
# epoch=0, i=624, loss=0.00314
# epoch=0, i=625, loss=0.00032
# epoch=0, i=626, loss=0.00497
# epoch=0, i=627, loss=0.00117
# epoch=0, i=628, loss=0.00097
# epoch=0, i=629, loss=0.00024
# epoch=0, i=630, loss=0.00484
# epoch=0, i=631, loss=0.00205
# epoch=0, i=632, loss=0.00040
# epoch=0, i=633, loss=0.00067
# epoch=0, i=634, loss=0.00038
# epoch=0, i=635, loss=0.01491
# epoch=0, i=636, loss=0.00113
# epoch=0, i=637, loss=0.00163
# epoch=0, i=638, loss=0.00014
# epoch=0, i=639, loss=0.00039
# epoch=0, i=640, loss=0.00712
# epoch=0, i=641, loss=0.00261
# epoch=0, i=642, loss=0.00216
# epoch=0, i=643, loss=0.00015
# epoch=0, i=644, loss=0.02605
# epoch=0, i=645, loss=0.00343
# epoch=0, i=646, loss=0.00001
# epoch=0, i=647, loss=0.00001
# epoch=0, i=648, loss=0.00664
# epoch=0, i=649, loss=0.01106
# epoch=0, i=650, loss=0.00059
# epoch=0, i=651, loss=0.00288
# epoch=0, i=652, loss=0.00690
# epoch=0, i=653, loss=0.00767
# epoch=0, i=654, loss=0.03862
# epoch=0, i=655, loss=0.00413
# epoch=0, i=656, loss=0.00970
# epoch=0, i=657, loss=0.00977
# epoch=0, i=658, loss=0.00188
# epoch=0, i=659, loss=0.00134
# epoch=0, i=660, loss=0.00559
# epoch=0, i=661, loss=0.00096
# epoch=0, i=662, loss=0.00570
# epoch=0, i=663, loss=0.01765
# epoch=0, i=664, loss=0.00748
# epoch=0, i=665, loss=0.00044
# epoch=0, i=666, loss=0.00264
# epoch=0, i=667, loss=0.00067
# epoch=0, i=668, loss=0.00151
# epoch=0, i=669, loss=0.00001
# epoch=0, i=670, loss=0.01078
# epoch=0, i=671, loss=0.00002
# epoch=0, i=672, loss=0.00026
# epoch=0, i=673, loss=0.01987
# epoch=0, i=674, loss=0.00469
# epoch=0, i=675, loss=0.00342
# epoch=0, i=676, loss=0.00330
# epoch=0, i=677, loss=0.00400
# epoch=0, i=678, loss=0.00050
# epoch=0, i=679, loss=0.00023
# epoch=0, i=680, loss=0.00370
# epoch=0, i=681, loss=0.00009
# epoch=0, i=682, loss=0.00018
# epoch=0, i=683, loss=0.00442
# epoch=0, i=684, loss=0.00078
# epoch=0, i=685, loss=0.00152
# epoch=0, i=686, loss=0.00038
# epoch=0, i=687, loss=0.02761
# epoch=0, i=688, loss=0.00073
# epoch=0, i=689, loss=0.00009
# epoch=0, i=690, loss=0.00257
# epoch=0, i=691, loss=0.01467
# epoch=0, i=692, loss=0.00001
# epoch=0, i=693, loss=0.00690
# epoch=0, i=694, loss=0.00686
# epoch=0, i=695, loss=0.00001
# epoch=0, i=696, loss=0.00761
# epoch=0, i=697, loss=0.01117
# epoch=0, i=698, loss=0.00006
# epoch=0, i=699, loss=0.00009
# epoch=0, i=700, loss=0.00182
# epoch=0, i=701, loss=0.00008
# epoch=0, i=702, loss=0.00069
# epoch=0, i=703, loss=0.00004
# epoch=0, i=704, loss=0.00006
# epoch=0, i=705, loss=0.00031
# epoch=0, i=706, loss=0.00050
# epoch=0, i=707, loss=0.00003
# epoch=0, i=708, loss=0.00389
# epoch=0, i=709, loss=0.00184
# epoch=0, i=710, loss=0.00688
# epoch=0, i=711, loss=0.04156
# epoch=0, i=712, loss=0.00319
# epoch=0, i=713, loss=0.00000
# epoch=0, i=714, loss=0.00254
# epoch=0, i=715, loss=0.00106
# epoch=0, i=716, loss=0.00015
# epoch=0, i=717, loss=0.00360
# epoch=0, i=718, loss=0.00657
# epoch=0, i=719, loss=0.00598
# epoch=0, i=720, loss=0.00132
# epoch=0, i=721, loss=0.00296
# epoch=0, i=722, loss=0.00023
# epoch=0, i=723, loss=0.00153
# epoch=0, i=724, loss=0.00475
# epoch=0, i=725, loss=0.00071
# epoch=0, i=726, loss=0.01135
# epoch=0, i=727, loss=0.00289
# epoch=0, i=728, loss=0.01090
# epoch=0, i=729, loss=0.00548
# epoch=0, i=730, loss=0.07533
# epoch=0, i=731, loss=0.00005
# epoch=0, i=732, loss=0.00786
# epoch=0, i=733, loss=0.00011
# epoch=0, i=734, loss=0.00549
# epoch=0, i=735, loss=0.00014
# epoch=0, i=736, loss=0.02148
# epoch=0, i=737, loss=0.00153
# epoch=0, i=738, loss=0.02714
# epoch=0, i=739, loss=0.01956
# epoch=0, i=740, loss=0.00210
# epoch=0, i=741, loss=0.00889
# epoch=0, i=742, loss=0.00784
# epoch=0, i=743, loss=0.00008
# epoch=0, i=744, loss=0.01185
# epoch=0, i=745, loss=0.00905
# epoch=0, i=746, loss=0.00380
# epoch=0, i=747, loss=0.01740
# epoch=0, i=748, loss=0.00011
# epoch=0, i=749, loss=0.00242
# epoch=0, i=750, loss=0.00058
# epoch=0, i=751, loss=0.00297
# epoch=0, i=752, loss=0.00082
# epoch=0, i=753, loss=0.00036
# epoch=0, i=754, loss=0.03695
# epoch=0, i=755, loss=0.00000
# epoch=0, i=756, loss=0.00284
# epoch=0, i=757, loss=0.00004
# epoch=0, i=758, loss=0.00016
# epoch=0, i=759, loss=0.00001
# epoch=0, i=760, loss=0.00062
# epoch=0, i=761, loss=0.00000
# epoch=0, i=762, loss=0.02297
# epoch=0, i=763, loss=0.00023
# epoch=0, i=764, loss=0.00746
# epoch=0, i=765, loss=0.00004
# epoch=0, i=766, loss=0.00031
# epoch=0, i=767, loss=0.00002
# epoch=0, i=768, loss=0.00000
# epoch=0, i=769, loss=0.00385
# epoch=0, i=770, loss=0.00135
# epoch=0, i=771, loss=0.00353
# epoch=0, i=772, loss=0.01767
# epoch=0, i=773, loss=0.00001
# epoch=0, i=774, loss=0.00017
# epoch=0, i=775, loss=0.00008
# epoch=0, i=776, loss=0.00639
# epoch=0, i=777, loss=0.01079
# epoch=0, i=778, loss=0.00029
# epoch=0, i=779, loss=0.00016
# epoch=0, i=780, loss=0.00000
# epoch=0, i=781, loss=0.00658
# epoch=0, i=782, loss=0.00068
# epoch=0, i=783, loss=0.00106
# epoch=0, i=784, loss=0.00659
# epoch=0, i=785, loss=0.00006
# epoch=0, i=786, loss=0.00002
# epoch=0, i=787, loss=0.00587
# epoch=0, i=788, loss=0.00420
# epoch=0, i=789, loss=0.00034
# epoch=0, i=790, loss=0.00003
# epoch=0, i=791, loss=0.00121
# epoch=0, i=792, loss=0.00119
# epoch=0, i=793, loss=0.00163
# epoch=0, i=794, loss=0.00036
# epoch=0, i=795, loss=0.00016
# epoch=0, i=796, loss=0.00044
# epoch=0, i=797, loss=0.00092
# epoch=0, i=798, loss=0.00046
# epoch=0, i=799, loss=0.00952
# epoch=0, i=800, loss=0.00130
# epoch=0, i=801, loss=0.00124
# epoch=0, i=802, loss=0.00003
# epoch=0, i=803, loss=0.00102
# epoch=0, i=804, loss=0.01346
# epoch=0, i=805, loss=0.01299
# epoch=0, i=806, loss=0.00004
# epoch=0, i=807, loss=0.00009
# epoch=0, i=808, loss=0.00015
# epoch=0, i=809, loss=0.00002
# epoch=0, i=810, loss=0.00034
# epoch=0, i=811, loss=0.00436
# epoch=0, i=812, loss=0.00280
# epoch=0, i=813, loss=0.00153
# epoch=0, i=814, loss=0.00182
# epoch=0, i=815, loss=0.00182
# epoch=0, i=816, loss=0.00016
# epoch=0, i=817, loss=0.00008
# epoch=0, i=818, loss=0.00010
# epoch=0, i=819, loss=0.00006
# epoch=0, i=820, loss=0.00024
# epoch=0, i=821, loss=0.00831
# epoch=0, i=822, loss=0.00000
# epoch=0, i=823, loss=0.00142
# epoch=0, i=824, loss=0.00052
# epoch=0, i=825, loss=0.00650
# epoch=0, i=826, loss=0.00020
# epoch=0, i=827, loss=0.00709
# epoch=0, i=828, loss=0.00101
# epoch=0, i=829, loss=0.00191
# epoch=0, i=830, loss=0.00002
# epoch=0, i=831, loss=0.00003
# epoch=0, i=832, loss=0.00388
# epoch=0, i=833, loss=0.00873
# epoch=0, i=834, loss=0.00038
# epoch=0, i=835, loss=0.00112
# epoch=0, i=836, loss=0.00182
# epoch=0, i=837, loss=0.00039
# epoch=0, i=838, loss=0.00197
# epoch=0, i=839, loss=0.00125
# epoch=0, i=840, loss=0.00267
# epoch=0, i=841, loss=0.00091
# epoch=0, i=842, loss=0.00527
# epoch=0, i=843, loss=0.00401
# epoch=0, i=844, loss=0.00520
# epoch=0, i=845, loss=0.00084
# epoch=0, i=846, loss=0.00626
# epoch=0, i=847, loss=0.00029
# epoch=0, i=848, loss=0.00149
# epoch=0, i=849, loss=0.00111
# epoch=0, i=850, loss=0.00823
# epoch=0, i=851, loss=0.00054
# epoch=0, i=852, loss=0.00023
# epoch=0, i=853, loss=0.00039
# epoch=0, i=854, loss=0.00187
# epoch=0, i=855, loss=0.00000
# epoch=0, i=856, loss=0.00001
# epoch=0, i=857, loss=0.00818
# epoch=0, i=858, loss=0.00486
# epoch=0, i=859, loss=0.00269
# epoch=0, i=860, loss=0.00097
# epoch=0, i=861, loss=0.00005
# epoch=0, i=862, loss=0.00408
# epoch=0, i=863, loss=0.00259
# epoch=0, i=864, loss=0.12539
# epoch=0, i=865, loss=0.00284
# epoch=0, i=866, loss=0.00205
# epoch=0, i=867, loss=0.00424
# epoch=0, i=868, loss=0.02284
# epoch=0, i=869, loss=0.00809
# epoch=0, i=870, loss=0.00224
# epoch=0, i=871, loss=0.06754
# epoch=0, i=872, loss=0.00144
# epoch=0, i=873, loss=0.00793
# epoch=0, i=874, loss=0.00251
# epoch=0, i=875, loss=0.01027
# epoch=0, i=876, loss=0.00076
# epoch=0, i=877, loss=0.00921
# epoch=0, i=878, loss=0.00043
# epoch=0, i=879, loss=0.00075
# epoch=0, i=880, loss=0.00955
# epoch=0, i=881, loss=0.00566
# epoch=0, i=882, loss=0.00325
# epoch=0, i=883, loss=0.00227
# epoch=0, i=884, loss=0.00004
# epoch=0, i=885, loss=0.00232
# epoch=0, i=886, loss=0.00515
# epoch=0, i=887, loss=0.00335
# epoch=0, i=888, loss=0.00396
# epoch=0, i=889, loss=0.00034
# epoch=0, i=890, loss=0.00244
# epoch=0, i=891, loss=0.00640
# epoch=0, i=892, loss=0.00762
# epoch=0, i=893, loss=0.00086
# epoch=0, i=894, loss=0.00274
# epoch=0, i=895, loss=0.00005
# epoch=0, i=896, loss=0.02451
# epoch=0, i=897, loss=0.01528
# epoch=0, i=898, loss=0.00375
# epoch=0, i=899, loss=0.00026
# epoch=0, i=900, loss=0.00947
# epoch=0, i=901, loss=0.00270
# epoch=0, i=902, loss=0.00270
# epoch=0, i=903, loss=0.00260
# epoch=0, i=904, loss=0.01672
# epoch=0, i=905, loss=0.00125
# epoch=0, i=906, loss=0.00094
# epoch=0, i=907, loss=0.00127
# epoch=0, i=908, loss=0.00094
# epoch=0, i=909, loss=0.00007
# epoch=0, i=910, loss=0.00332
# epoch=0, i=911, loss=0.00429
# epoch=0, i=912, loss=0.00513
# epoch=0, i=913, loss=0.01419
# epoch=0, i=914, loss=0.00542
# epoch=0, i=915, loss=0.10586
# epoch=0, i=916, loss=0.01609
# epoch=0, i=917, loss=0.00021
# epoch=0, i=918, loss=0.00158
# epoch=0, i=919, loss=0.01703
# epoch=0, i=920, loss=0.00011
# epoch=0, i=921, loss=0.00004
# epoch=0, i=922, loss=0.00046
# epoch=0, i=923, loss=0.00446
# epoch=0, i=924, loss=0.00449
# epoch=0, i=925, loss=0.00460
# epoch=0, i=926, loss=0.01506
# epoch=0, i=927, loss=0.00051
# epoch=0, i=928, loss=0.00189
# epoch=0, i=929, loss=0.00183
# epoch=0, i=930, loss=0.00010
# epoch=0, i=931, loss=0.00002
# epoch=0, i=932, loss=0.00727
# epoch=0, i=933, loss=0.00001
# epoch=0, i=934, loss=0.00005
# epoch=0, i=935, loss=0.00000
# epoch=0, i=936, loss=0.00049
# epoch=0, i=937, loss=0.00110
# epoch=0, i=938, loss=0.01818
# epoch=0, i=939, loss=0.00712
# epoch=0, i=940, loss=0.00080
# epoch=0, i=941, loss=0.00632
# epoch=0, i=942, loss=0.00077
# epoch=0, i=943, loss=0.00056
# epoch=0, i=944, loss=0.00017
# epoch=0, i=945, loss=0.01930
# epoch=0, i=946, loss=0.00013
# epoch=0, i=947, loss=0.00006
# epoch=0, i=948, loss=0.00013
# epoch=0, i=949, loss=0.00389
# epoch=0, i=950, loss=0.00000
# epoch=0, i=951, loss=0.00970
# epoch=0, i=952, loss=0.00150
# epoch=0, i=953, loss=0.00145
# epoch=0, i=954, loss=0.00753
# epoch=0, i=955, loss=0.00165
# epoch=0, i=956, loss=0.00575
# epoch=0, i=957, loss=0.00015
# epoch=0, i=958, loss=0.02907
# epoch=0, i=959, loss=0.00000
# epoch=0, i=960, loss=0.00921
# epoch=0, i=961, loss=0.00299
# epoch=0, i=962, loss=0.00027
# epoch=0, i=963, loss=0.00262
# epoch=0, i=964, loss=0.03118
# epoch=0, i=965, loss=0.00210
# epoch=0, i=966, loss=0.00042
# epoch=0, i=967, loss=0.00008
# epoch=0, i=968, loss=0.00507
# epoch=0, i=969, loss=0.00266
# epoch=0, i=970, loss=0.00665
# epoch=0, i=971, loss=0.00004
# epoch=0, i=972, loss=0.00080
# epoch=0, i=973, loss=0.00595
# epoch=0, i=974, loss=0.00096
# epoch=0, i=975, loss=0.00006
# epoch=0, i=976, loss=0.00086
# epoch=0, i=977, loss=0.00019
# epoch=0, i=978, loss=0.00261
# epoch=0, i=979, loss=0.01112
# epoch=0, i=980, loss=0.00143
# epoch=0, i=981, loss=0.00003
# epoch=0, i=982, loss=0.00714
# epoch=0, i=983, loss=0.00059
# epoch=0, i=984, loss=0.00321
# epoch=0, i=985, loss=0.00178
# epoch=0, i=986, loss=0.00198
# epoch=0, i=987, loss=0.00082
# epoch=0, i=988, loss=0.00015
# epoch=0, i=989, loss=0.00232
# epoch=0, i=990, loss=0.00096
# epoch=0, i=991, loss=0.00002
# epoch=0, i=992, loss=0.01527
# epoch=0, i=993, loss=0.01714
# epoch=0, i=994, loss=0.00738
# epoch=0, i=995, loss=0.00917
# epoch=0, i=996, loss=0.00561
# epoch=0, i=997, loss=0.00162
# epoch=0, i=998, loss=0.00056
# epoch=0, i=999, loss=0.00170
# epoch=0, i=1000, loss=0.01980
# epoch=0, i=1001, loss=0.00446
# epoch=0, i=1002, loss=0.00453
# epoch=0, i=1003, loss=0.00006
# epoch=0, i=1004, loss=0.00736
# epoch=0, i=1005, loss=0.00017
# epoch=0, i=1006, loss=0.00000
# epoch=0, i=1007, loss=0.00653
# epoch=0, i=1008, loss=0.00175
# epoch=0, i=1009, loss=0.00008
# epoch=0, i=1010, loss=0.00020
# epoch=0, i=1011, loss=0.01028
# epoch=0, i=1012, loss=0.00522
# epoch=0, i=1013, loss=0.00100
# epoch=0, i=1014, loss=0.00115
# epoch=0, i=1015, loss=0.01041
# epoch=0, i=1016, loss=0.00046
# epoch=0, i=1017, loss=0.00002
# epoch=0, i=1018, loss=0.01047
# epoch=0, i=1019, loss=0.01227
# epoch=0, i=1020, loss=0.00071
# epoch=0, i=1021, loss=0.01977
# epoch=0, i=1022, loss=0.00871
# epoch=0, i=1023, loss=0.00218
# epoch=0, i=1024, loss=0.00529
# epoch=0, i=1025, loss=0.00002
# epoch=0, i=1026, loss=0.01159
# epoch=0, i=1027, loss=0.01271
# epoch=0, i=1028, loss=0.01127
# epoch=0, i=1029, loss=0.00134
# epoch=0, i=1030, loss=0.02237
# epoch=0, i=1031, loss=0.00790
# epoch=0, i=1032, loss=0.00835
# epoch=0, i=1033, loss=0.00017
# epoch=0, i=1034, loss=0.00563
# epoch=0, i=1035, loss=0.01423
# epoch=0, i=1036, loss=0.00463
# epoch=0, i=1037, loss=0.00034
# epoch=0, i=1038, loss=0.00354
# epoch=0, i=1039, loss=0.01049
# epoch=0, i=1040, loss=0.00882
# epoch=0, i=1041, loss=0.01814
# epoch=0, i=1042, loss=0.00808
# epoch=0, i=1043, loss=0.00293
# epoch=0, i=1044, loss=0.01749
# epoch=0, i=1045, loss=0.01682
# epoch=0, i=1046, loss=0.00060
# epoch=0, i=1047, loss=0.00026
# epoch=0, i=1048, loss=0.00034
# epoch=0, i=1049, loss=0.00170
# epoch=0, i=1050, loss=0.00013
# epoch=0, i=1051, loss=0.03031
# epoch=0, i=1052, loss=0.00577
# epoch=0, i=1053, loss=0.00591
# epoch=0, i=1054, loss=0.00040
# epoch=0, i=1055, loss=0.01171
# epoch=0, i=1056, loss=0.03071
# epoch=0, i=1057, loss=0.00051
# epoch=0, i=1058, loss=0.00061
# epoch=0, i=1059, loss=0.00508
# epoch=0, i=1060, loss=0.00755
# epoch=0, i=1061, loss=0.07065
# epoch=0, i=1062, loss=0.00036
# epoch=0, i=1063, loss=0.01004
# epoch=0, i=1064, loss=0.00037
# epoch=0, i=1065, loss=0.01440
# epoch=0, i=1066, loss=0.01496
# epoch=0, i=1067, loss=0.00000
# epoch=0, i=1068, loss=0.00216
# epoch=0, i=1069, loss=0.00160
# epoch=0, i=1070, loss=0.00529
# epoch=0, i=1071, loss=0.07733
# epoch=0, i=1072, loss=0.00183
# epoch=0, i=1073, loss=0.00181
# epoch=0, i=1074, loss=0.00022
# epoch=0, i=1075, loss=0.00023
# epoch=0, i=1076, loss=0.00664
# epoch=0, i=1077, loss=0.00000
# epoch=0, i=1078, loss=0.00392
# epoch=0, i=1079, loss=0.01560
# epoch=0, i=1080, loss=0.01485
# epoch=0, i=1081, loss=0.01050
# epoch=0, i=1082, loss=0.02860
# epoch=0, i=1083, loss=0.03308
# epoch=0, i=1084, loss=0.00411
# epoch=0, i=1085, loss=0.00176
# epoch=0, i=1086, loss=0.01554
# epoch=0, i=1087, loss=0.01455
# epoch=0, i=1088, loss=0.02080
# epoch=0, i=1089, loss=0.00135
# epoch=0, i=1090, loss=0.02092
# epoch=0, i=1091, loss=0.01828
# epoch=0, i=1092, loss=0.01676
# epoch=0, i=1093, loss=0.05216
# epoch=0, i=1094, loss=0.04542
# epoch=0, i=1095, loss=0.01995
# epoch=0, i=1096, loss=0.00148
# epoch=0, i=1097, loss=0.02508
# epoch=0, i=1098, loss=0.00442
# epoch=0, i=1099, loss=0.01677
# epoch=0, i=1100, loss=0.07214
# epoch=0, i=1101, loss=0.00854
# epoch=0, i=1102, loss=0.03059
# epoch=0, i=1103, loss=0.01378
# epoch=0, i=1104, loss=0.02660
# epoch=0, i=1105, loss=0.00429
# epoch=0, i=1106, loss=0.00182
# epoch=0, i=1107, loss=0.00751
# epoch=0, i=1108, loss=0.02815
# epoch=0, i=1109, loss=0.00047
# epoch=0, i=1110, loss=0.04009
# epoch=0, i=1111, loss=0.00343
# epoch=0, i=1112, loss=0.00081
# epoch=0, i=1113, loss=0.02942
# epoch=0, i=1114, loss=0.07161
# epoch=0, i=1115, loss=0.02342
# epoch=0, i=1116, loss=0.00626
# epoch=0, i=1117, loss=0.00036
# epoch=0, i=1118, loss=0.00724
# epoch=0, i=1119, loss=0.03441
# epoch=0, i=1120, loss=0.00776
# epoch=0, i=1121, loss=0.00513
# epoch=0, i=1122, loss=0.00093
# epoch=0, i=1123, loss=0.00208
# epoch=0, i=1124, loss=0.00043
# epoch=0, i=1125, loss=0.00766
# epoch=0, i=1126, loss=0.00312
# epoch=0, i=1127, loss=0.00062
# epoch=0, i=1128, loss=0.04988
# epoch=0, i=1129, loss=0.00037
# epoch=0, i=1130, loss=0.00435
# epoch=0, i=1131, loss=0.00207
# epoch=0, i=1132, loss=0.00053
# epoch=0, i=1133, loss=0.00067
# epoch=0, i=1134, loss=0.00039
# epoch=0, i=1135, loss=0.02134
# epoch=0, i=1136, loss=0.01219
# epoch=0, i=1137, loss=0.00130
# epoch=0, i=1138, loss=0.00037
# epoch=0, i=1139, loss=0.00003
# epoch=0, i=1140, loss=0.00087
# epoch=0, i=1141, loss=0.00502
# epoch=0, i=1142, loss=0.00853
# epoch=0, i=1143, loss=0.00000
# epoch=0, i=1144, loss=0.00697
# epoch=0, i=1145, loss=0.05005
# epoch=0, i=1146, loss=0.00101
# epoch=0, i=1147, loss=0.00942
# epoch=0, i=1148, loss=0.03440
# epoch=0, i=1149, loss=0.00931
# epoch=0, i=1150, loss=0.00134
# epoch=0, i=1151, loss=0.01268
# epoch=0, i=1152, loss=0.00711
# epoch=0, i=1153, loss=0.00123
# epoch=0, i=1154, loss=0.00176
# epoch=0, i=1155, loss=0.00085
# epoch=0, i=1156, loss=0.00009
# epoch=0, i=1157, loss=0.01654
# epoch=0, i=1158, loss=0.00156
# epoch=0, i=1159, loss=0.02224
# epoch=0, i=1160, loss=0.04824
# epoch=0, i=1161, loss=0.00341
# epoch=0, i=1162, loss=0.00011
# epoch=0, i=1163, loss=0.00268
# epoch=0, i=1164, loss=0.05472
# epoch=0, i=1165, loss=0.00004
# epoch=0, i=1166, loss=0.00012
# epoch=0, i=1167, loss=0.00507
# epoch=0, i=1168, loss=0.00026
# epoch=0, i=1169, loss=0.00000
# epoch=0, i=1170, loss=0.00192
# epoch=0, i=1171, loss=0.00034
# epoch=0, i=1172, loss=0.00314
# epoch=0, i=1173, loss=0.00001
# epoch=0, i=1174, loss=0.00173
# epoch=0, i=1175, loss=0.05517
# epoch=0, i=1176, loss=0.06035
# epoch=0, i=1177, loss=0.00007
# epoch=0, i=1178, loss=0.04073
# epoch=0, i=1179, loss=0.00385
# epoch=0, i=1180, loss=0.00112
# epoch=0, i=1181, loss=0.00000
# epoch=0, i=1182, loss=0.00831
# epoch=0, i=1183, loss=0.00349
# epoch=0, i=1184, loss=0.00080
# epoch=0, i=1185, loss=0.03020
# epoch=0, i=1186, loss=0.00456
# epoch=0, i=1187, loss=0.00014
# epoch=0, i=1188, loss=0.05768
# epoch=0, i=1189, loss=0.00125
# epoch=0, i=1190, loss=0.02213
# epoch=0, i=1191, loss=0.00762
# epoch=0, i=1192, loss=0.00884
# epoch=0, i=1193, loss=0.00727
# epoch=0, i=1194, loss=0.00235
# epoch=0, i=1195, loss=0.02244
# epoch=0, i=1196, loss=0.01173
# epoch=0, i=1197, loss=0.00483
# epoch=0, i=1198, loss=0.01642
# epoch=0, i=1199, loss=0.00151
# epoch=0, i=1200, loss=0.00415
# epoch=0, i=1201, loss=0.00339
# epoch=0, i=1202, loss=0.00293
# epoch=0, i=1203, loss=0.04138
# epoch=0, i=1204, loss=0.05306
# epoch=0, i=1205, loss=0.00621
# epoch=0, i=1206, loss=0.00010
# epoch=0, i=1207, loss=0.00183
# epoch=0, i=1208, loss=0.01102
# epoch=0, i=1209, loss=0.06491
# epoch=0, i=1210, loss=0.00208
# epoch=0, i=1211, loss=0.00454
# epoch=0, i=1212, loss=0.02612
# epoch=0, i=1213, loss=0.00003
# epoch=0, i=1214, loss=0.00000
# epoch=0, i=1215, loss=0.00041
# epoch=0, i=1216, loss=0.00090
# epoch=0, i=1217, loss=0.00190
# epoch=0, i=1218, loss=0.00016
# epoch=0, i=1219, loss=0.00027
# epoch=0, i=1220, loss=0.00958
# epoch=0, i=1221, loss=0.00277
# epoch=0, i=1222, loss=0.09143
# epoch=0, i=1223, loss=0.00351
# epoch=0, i=1224, loss=0.00015
# epoch=0, i=1225, loss=0.01361
# epoch=0, i=1226, loss=0.02611
# epoch=0, i=1227, loss=0.00065
# epoch=0, i=1228, loss=0.00754
# epoch=0, i=1229, loss=0.00143
# epoch=0, i=1230, loss=0.00720
# epoch=0, i=1231, loss=0.01263
# epoch=0, i=1232, loss=0.03047
# epoch=0, i=1233, loss=0.09566
# epoch=0, i=1234, loss=0.00004
# epoch=0, i=1235, loss=0.00116
# epoch=0, i=1236, loss=0.00025
# epoch=0, i=1237, loss=0.01611
# epoch=0, i=1238, loss=0.02471
# epoch=0, i=1239, loss=0.02001
# epoch=0, i=1240, loss=0.02409
# epoch=0, i=1241, loss=0.00115
# epoch=0, i=1242, loss=0.00009
# epoch=0, i=1243, loss=0.00196
# epoch=0, i=1244, loss=0.01372
# epoch=0, i=1245, loss=0.00441
# epoch=0, i=1246, loss=0.00095
# epoch=0, i=1247, loss=0.01160
# epoch=0, i=1248, loss=0.00041
# epoch=0, i=1249, loss=0.02358
# epoch=0, i=1250, loss=0.00202
# epoch=0, i=1251, loss=0.00247
# epoch=0, i=1252, loss=0.00006
# epoch=0, i=1253, loss=0.00221
# epoch=0, i=1254, loss=0.00218
# epoch=0, i=1255, loss=0.01365
# epoch=0, i=1256, loss=0.00198
# epoch=0, i=1257, loss=0.00885
# epoch=0, i=1258, loss=0.04169
# epoch=0, i=1259, loss=0.00205
# epoch=0, i=1260, loss=0.00418
# epoch=0, i=1261, loss=0.01151
# epoch=0, i=1262, loss=0.00505
# epoch=0, i=1263, loss=0.07450
# epoch=0, i=1264, loss=0.00018
# epoch=0, i=1265, loss=0.00270
# epoch=0, i=1266, loss=0.03079
# epoch=0, i=1267, loss=0.00954
# epoch=0, i=1268, loss=0.00493
# epoch=0, i=1269, loss=0.00217
# epoch=0, i=1270, loss=0.01653
# epoch=0, i=1271, loss=0.00889
# epoch=0, i=1272, loss=0.00351
# epoch=0, i=1273, loss=0.00191
# epoch=0, i=1274, loss=0.01404
# epoch=0, i=1275, loss=0.01811
# epoch=0, i=1276, loss=0.00701
# epoch=0, i=1277, loss=0.01926
# epoch=0, i=1278, loss=0.00450
# epoch=0, i=1279, loss=0.00006
# epoch=0, i=1280, loss=0.00006
# epoch=0, i=1281, loss=0.00059
# epoch=0, i=1282, loss=0.01685
# epoch=0, i=1283, loss=0.01594
# epoch=0, i=1284, loss=0.00021
# epoch=0, i=1285, loss=0.00722
# epoch=0, i=1286, loss=0.05087
# epoch=0, i=1287, loss=0.00652
# epoch=0, i=1288, loss=0.00012
# epoch=0, i=1289, loss=0.00662
# epoch=0, i=1290, loss=0.01197
# epoch=0, i=1291, loss=0.00112
# epoch=0, i=1292, loss=0.01138
# epoch=0, i=1293, loss=0.01336
# epoch=0, i=1294, loss=0.00032
# epoch=0, i=1295, loss=0.00253
# epoch=0, i=1296, loss=0.00412
# epoch=0, i=1297, loss=0.00660
# epoch=0, i=1298, loss=0.00339
# epoch=0, i=1299, loss=0.00285
# epoch=0, i=1300, loss=0.00024
# epoch=0, i=1301, loss=0.05082
# epoch=0, i=1302, loss=0.00193
# epoch=0, i=1303, loss=0.00436
# epoch=0, i=1304, loss=0.00207
# epoch=0, i=1305, loss=0.00882
# epoch=0, i=1306, loss=0.00002
# epoch=0, i=1307, loss=0.00026
# epoch=0, i=1308, loss=0.00215
# epoch=0, i=1309, loss=0.00680
# epoch=0, i=1310, loss=0.01473
# epoch=0, i=1311, loss=0.00494
# epoch=0, i=1312, loss=0.01707
# epoch=0, i=1313, loss=0.03857
# epoch=0, i=1314, loss=0.00009
# epoch=0, i=1315, loss=0.00864
# epoch=0, i=1316, loss=0.00771
# epoch=0, i=1317, loss=0.00472
# epoch=0, i=1318, loss=0.00813
# epoch=0, i=1319, loss=0.00074
# epoch=0, i=1320, loss=0.00050
# epoch=0, i=1321, loss=0.03301
# epoch=0, i=1322, loss=0.00091
# epoch=0, i=1323, loss=0.00086
# epoch=0, i=1324, loss=0.00374
# epoch=0, i=1325, loss=0.00261
# epoch=0, i=1326, loss=0.00425
# epoch=0, i=1327, loss=0.01169
# epoch=0, i=1328, loss=0.00697
# epoch=0, i=1329, loss=0.00161
# epoch=0, i=1330, loss=0.03474
# epoch=0, i=1331, loss=0.00077
# epoch=0, i=1332, loss=0.01478
# epoch=0, i=1333, loss=0.04086
# epoch=0, i=1334, loss=0.00181
# epoch=0, i=1335, loss=0.00119
# epoch=0, i=1336, loss=0.03032
# epoch=0, i=1337, loss=0.03044
# epoch=0, i=1338, loss=0.01985
# epoch=0, i=1339, loss=0.00031
# epoch=0, i=1340, loss=0.00748
# epoch=0, i=1341, loss=0.04164
# epoch=0, i=1342, loss=0.00468
# epoch=0, i=1343, loss=0.03180
# epoch=0, i=1344, loss=0.00083
# epoch=0, i=1345, loss=0.00398
# epoch=0, i=1346, loss=0.10335
# epoch=0, i=1347, loss=0.00032
# epoch=0, i=1348, loss=0.00791
# epoch=0, i=1349, loss=0.00091
# epoch=0, i=1350, loss=0.01120
# epoch=0, i=1351, loss=0.01870
# epoch=0, i=1352, loss=0.00546
# epoch=0, i=1353, loss=0.02789
# epoch=0, i=1354, loss=0.00254
# epoch=0, i=1355, loss=0.02946
# epoch=0, i=1356, loss=0.00004
# epoch=0, i=1357, loss=0.02603
# epoch=0, i=1358, loss=0.03537
# epoch=0, i=1359, loss=0.00129
# epoch=0, i=1360, loss=0.00084
# epoch=0, i=1361, loss=0.02113
# epoch=0, i=1362, loss=0.01504
# epoch=0, i=1363, loss=0.00802
# epoch=0, i=1364, loss=0.02745
# epoch=0, i=1365, loss=0.00055
# epoch=0, i=1366, loss=0.03865
# epoch=0, i=1367, loss=0.00165
# epoch=0, i=1368, loss=0.01983
# epoch=0, i=1369, loss=0.01064
# epoch=0, i=1370, loss=0.00614
# epoch=0, i=1371, loss=0.00222
# epoch=0, i=1372, loss=0.00086
# epoch=0, i=1373, loss=0.02930
# epoch=0, i=1374, loss=0.02855
# epoch=0, i=1375, loss=0.00000
# epoch=0, i=1376, loss=0.01860
# epoch=0, i=1377, loss=0.02002
# epoch=0, i=1378, loss=0.02494
# epoch=0, i=1379, loss=0.00037
# epoch=0, i=1380, loss=0.05153
# epoch=0, i=1381, loss=0.00043
# epoch=0, i=1382, loss=0.00135
# epoch=0, i=1383, loss=0.00307
# epoch=0, i=1384, loss=0.00775
# epoch=0, i=1385, loss=0.00535
# epoch=0, i=1386, loss=0.00038
# epoch=0, i=1387, loss=0.03527
# epoch=0, i=1388, loss=0.01001
# epoch=0, i=1389, loss=0.00506
# epoch=0, i=1390, loss=0.07586
# epoch=0, i=1391, loss=0.00003
# epoch=0, i=1392, loss=0.00066
# epoch=0, i=1393, loss=0.00077
# epoch=0, i=1394, loss=0.00007
# epoch=0, i=1395, loss=0.02011
# epoch=0, i=1396, loss=0.00992
# epoch=0, i=1397, loss=0.02629
# epoch=0, i=1398, loss=0.09349
# epoch=0, i=1399, loss=0.00544
# epoch=0, i=1400, loss=0.00815
# epoch=0, i=1401, loss=0.00001
# epoch=0, i=1402, loss=0.02764
# epoch=0, i=1403, loss=0.00109
# epoch=0, i=1404, loss=0.01340
# epoch=0, i=1405, loss=0.01402
# epoch=0, i=1406, loss=0.00000
# epoch=0, i=1407, loss=0.03650
# epoch=0, i=1408, loss=0.00088
# epoch=0, i=1409, loss=0.00825
# epoch=0, i=1410, loss=0.01682
# epoch=0, i=1411, loss=0.00222
# epoch=0, i=1412, loss=0.00000
# epoch=0, i=1413, loss=0.00689
# epoch=0, i=1414, loss=0.01688
# epoch=0, i=1415, loss=0.00150
# epoch=0, i=1416, loss=0.00209
# epoch=0, i=1417, loss=0.00020
# epoch=0, i=1418, loss=0.00609
# epoch=0, i=1419, loss=0.00010
# epoch=0, i=1420, loss=0.01214
# epoch=0, i=1421, loss=0.00391
# epoch=0, i=1422, loss=0.00009
# epoch=0, i=1423, loss=0.00037
# epoch=0, i=1424, loss=0.00809
# epoch=0, i=1425, loss=0.00233
# epoch=0, i=1426, loss=0.00134
# epoch=0, i=1427, loss=0.10720
# epoch=0, i=1428, loss=0.02232
# epoch=0, i=1429, loss=0.00293
# epoch=0, i=1430, loss=0.00056
# epoch=0, i=1431, loss=0.01951
# epoch=0, i=1432, loss=0.00001
# epoch=0, i=1433, loss=0.03231
# epoch=0, i=1434, loss=0.00922
# epoch=0, i=1435, loss=0.02801
# epoch=0, i=1436, loss=0.00536
# epoch=0, i=1437, loss=0.00408
# epoch=0, i=1438, loss=0.01094
# epoch=0, i=1439, loss=0.00000
# epoch=0, i=1440, loss=0.00029
# epoch=0, i=1441, loss=0.01962
# epoch=0, i=1442, loss=0.08865
# epoch=0, i=1443, loss=0.00001
# epoch=0, i=1444, loss=0.00678
# epoch=0, i=1445, loss=0.00207
# epoch=0, i=1446, loss=0.05355
# epoch=0, i=1447, loss=0.00116
# epoch=0, i=1448, loss=0.04407
# epoch=0, i=1449, loss=0.00191
# epoch=0, i=1450, loss=0.00065
# epoch=0, i=1451, loss=0.00580
# epoch=0, i=1452, loss=0.01660
# epoch=0, i=1453, loss=0.01427
# epoch=0, i=1454, loss=0.00000
# epoch=0, i=1455, loss=0.01459
# epoch=0, i=1456, loss=0.03460
# epoch=0, i=1457, loss=0.00290
# epoch=0, i=1458, loss=0.00220
# epoch=0, i=1459, loss=0.06055
# epoch=0, i=1460, loss=0.00000
# epoch=0, i=1461, loss=0.00065
# epoch=0, i=1462, loss=0.00280
# epoch=0, i=1463, loss=0.00115
# epoch=0, i=1464, loss=0.00533
# epoch=0, i=1465, loss=0.01098
# epoch=0, i=1466, loss=0.00001
# epoch=0, i=1467, loss=0.00421
# epoch=0, i=1468, loss=0.00366
# epoch=0, i=1469, loss=0.00701
# epoch=0, i=1470, loss=0.01156
# epoch=0, i=1471, loss=0.01074
# epoch=0, i=1472, loss=0.00207
# epoch=0, i=1473, loss=0.00404
# epoch=0, i=1474, loss=0.00032
# epoch=0, i=1475, loss=0.00402
# epoch=0, i=1476, loss=0.01474
# epoch=0, i=1477, loss=0.01088
# epoch=0, i=1478, loss=0.11346
# epoch=0, i=1479, loss=0.00781
# epoch=0, i=1480, loss=0.00097
# epoch=0, i=1481, loss=0.00018
# epoch=0, i=1482, loss=0.00079
# epoch=0, i=1483, loss=0.00001
# epoch=0, i=1484, loss=0.00012
# epoch=0, i=1485, loss=0.00035
# epoch=0, i=1486, loss=0.04529
# epoch=0, i=1487, loss=0.01267
# epoch=0, i=1488, loss=0.00229
# epoch=0, i=1489, loss=0.00297
# epoch=0, i=1490, loss=0.00063
# epoch=0, i=1491, loss=0.00276
# epoch=0, i=1492, loss=0.00061
# epoch=0, i=1493, loss=0.00056
# epoch=0, i=1494, loss=0.07855
# epoch=0, i=1495, loss=0.00057
# epoch=0, i=1496, loss=0.09361
# epoch=0, i=1497, loss=0.08946
# epoch=0, i=1498, loss=0.01355
# epoch=0, i=1499, loss=0.12086
# epoch=0, i=1500, loss=0.14675
# epoch=0, i=1501, loss=0.01913
# epoch=0, i=1502, loss=0.00100
# epoch=0, i=1503, loss=0.02764
# epoch=0, i=1504, loss=0.00212
# epoch=0, i=1505, loss=0.08350
# epoch=0, i=1506, loss=0.00000
# epoch=0, i=1507, loss=0.05680
# epoch=0, i=1508, loss=0.00887
# epoch=0, i=1509, loss=0.00767
# epoch=0, i=1510, loss=0.13270
# epoch=0, i=1511, loss=0.00000
# epoch=0, i=1512, loss=0.01241
# epoch=0, i=1513, loss=0.02209
# epoch=0, i=1514, loss=0.00003
# epoch=0, i=1515, loss=0.03841
# epoch=0, i=1516, loss=0.00021
# epoch=0, i=1517, loss=0.00410
# epoch=0, i=1518, loss=0.01068
# epoch=0, i=1519, loss=0.08354
# epoch=0, i=1520, loss=0.05331
# epoch=0, i=1521, loss=0.05341
# epoch=0, i=1522, loss=0.00047
# epoch=0, i=1523, loss=0.03390
# epoch=0, i=1524, loss=0.00646
# epoch=0, i=1525, loss=0.00697
# epoch=0, i=1526, loss=0.00128
# epoch=0, i=1527, loss=0.12931
# epoch=0, i=1528, loss=0.01431
# epoch=0, i=1529, loss=0.02663
# epoch=0, i=1530, loss=0.11370
# epoch=0, i=1531, loss=0.00071
# epoch=0, i=1532, loss=0.00816
# epoch=0, i=1533, loss=0.01764
# epoch=0, i=1534, loss=0.00599
# epoch=0, i=1535, loss=0.01748
# epoch=0, i=1536, loss=0.08414
# epoch=0, i=1537, loss=0.05559
# epoch=0, i=1538, loss=0.01020
# epoch=0, i=1539, loss=0.00038
# epoch=0, i=1540, loss=0.02267
# epoch=0, i=1541, loss=0.00077
# epoch=0, i=1542, loss=0.00013
# epoch=0, i=1543, loss=0.00309
# epoch=0, i=1544, loss=0.02132
# epoch=0, i=1545, loss=0.00418
# epoch=0, i=1546, loss=0.00093
# epoch=0, i=1547, loss=0.05210
# epoch=0, i=1548, loss=0.01185
# epoch=0, i=1549, loss=0.00407
# epoch=0, i=1550, loss=0.07002
# epoch=0, i=1551, loss=0.02245
# epoch=0, i=1552, loss=0.05882
# epoch=0, i=1553, loss=0.00798
# epoch=0, i=1554, loss=0.04001
# epoch=0, i=1555, loss=0.00031
# epoch=0, i=1556, loss=0.00044
# epoch=0, i=1557, loss=0.00043
# epoch=0, i=1558, loss=0.04487
# epoch=0, i=1559, loss=0.00033
# epoch=0, i=1560, loss=0.00202
# epoch=0, i=1561, loss=0.02157
# epoch=0, i=1562, loss=0.00170
# epoch=0, i=1563, loss=0.00221
# epoch=0, i=1564, loss=0.00043
# epoch=0, i=1565, loss=0.00059
# epoch=0, i=1566, loss=0.00006
# epoch=0, i=1567, loss=0.00005
# epoch=0, i=1568, loss=0.01107
# epoch=0, i=1569, loss=0.01456
# epoch=0, i=1570, loss=0.00064
# epoch=0, i=1571, loss=0.02074
# epoch=0, i=1572, loss=0.00721
# epoch=0, i=1573, loss=0.00148
# epoch=0, i=1574, loss=0.00671
# epoch=0, i=1575, loss=0.05281
# epoch=0, i=1576, loss=0.00323
# epoch=0, i=1577, loss=0.02629
# epoch=0, i=1578, loss=0.00821
# epoch=0, i=1579, loss=0.00036
# epoch=0, i=1580, loss=0.00113
# epoch=0, i=1581, loss=0.00026
# epoch=0, i=1582, loss=0.00401
# epoch=0, i=1583, loss=0.00039
# epoch=0, i=1584, loss=0.00976
# epoch=0, i=1585, loss=0.01962
# epoch=0, i=1586, loss=0.00008
# epoch=0, i=1587, loss=0.00698
# epoch=0, i=1588, loss=0.00024
# epoch=0, i=1589, loss=0.00343
# epoch=0, i=1590, loss=0.00009
# epoch=0, i=1591, loss=0.02254
# epoch=0, i=1592, loss=0.00629
# epoch=0, i=1593, loss=0.04504
# epoch=0, i=1594, loss=0.01743
# epoch=0, i=1595, loss=0.03840
# epoch=0, i=1596, loss=0.00771
# epoch=0, i=1597, loss=0.00003
# epoch=0, i=1598, loss=0.01419
# epoch=0, i=1599, loss=0.03550
# epoch=0, i=1600, loss=0.07967
# epoch=0, i=1601, loss=0.02245
# epoch=0, i=1602, loss=0.00076
# epoch=0, i=1603, loss=0.00320
# epoch=0, i=1604, loss=0.01659
# epoch=0, i=1605, loss=0.05750
# epoch=0, i=1606, loss=0.01263
# epoch=0, i=1607, loss=0.00001
# epoch=0, i=1608, loss=0.03136
# epoch=0, i=1609, loss=0.00003
# epoch=0, i=1610, loss=0.00310
# epoch=0, i=1611, loss=0.00340
# epoch=0, i=1612, loss=0.00157
# epoch=0, i=1613, loss=0.00827
# epoch=0, i=1614, loss=0.01076
# epoch=0, i=1615, loss=0.00054
# epoch=0, i=1616, loss=0.00293
# epoch=0, i=1617, loss=0.00249
# epoch=0, i=1618, loss=0.00413
# epoch=0, i=1619, loss=0.00064
# epoch=0, i=1620, loss=0.00238
# epoch=0, i=1621, loss=0.04353
# epoch=0, i=1622, loss=0.00085
# epoch=0, i=1623, loss=0.00002
# epoch=0, i=1624, loss=0.00216
# epoch=0, i=1625, loss=0.00081
# epoch=0, i=1626, loss=0.00423
# epoch=0, i=1627, loss=0.00159
# epoch=0, i=1628, loss=0.00592
# epoch=0, i=1629, loss=0.03845
# epoch=0, i=1630, loss=0.00000
# epoch=0, i=1631, loss=0.00558
# epoch=0, i=1632, loss=0.00642
# epoch=0, i=1633, loss=0.00052
# epoch=0, i=1634, loss=0.00047
# epoch=0, i=1635, loss=0.00005
# epoch=0, i=1636, loss=0.00261
# ...
# epoch=1, i=3477, loss=0.00001
# epoch=1, i=3478, loss=0.00072
# epoch=1, i=3479, loss=0.00016
# epoch=1, i=3480, loss=0.00000
# epoch=1, i=3481, loss=0.00046
# epoch=1, i=3482, loss=0.00518
# epoch=1, i=3483, loss=0.00003
# epoch=1, i=3484, loss=0.00414
# epoch=1, i=3485, loss=0.00017
# epoch=1, i=3486, loss=0.01032
# epoch=1, i=3487, loss=0.00019
# epoch=1, i=3488, loss=0.00105
# epoch=1, i=3489, loss=0.00172
# epoch=1, i=3490, loss=0.00000
# epoch=1, i=3491, loss=0.00033
# epoch=1, i=3492, loss=0.00055
# epoch=1, i=3493, loss=0.00067
# epoch=1, i=3494, loss=0.00007
# epoch=1, i=3495, loss=0.00031
# epoch=1, i=3496, loss=0.00062
# epoch=1, i=3497, loss=0.00038
# epoch=1, i=3498, loss=0.00423
# epoch=1, i=3499, loss=0.00010
# epoch=1, i=3500, loss=0.00019
# epoch=1, i=3501, loss=0.00066
# epoch=1, i=3502, loss=0.00002
# epoch=1, i=3503, loss=0.00000
# epoch=1, i=3504, loss=0.00001
# epoch=1, i=3505, loss=0.00004
# epoch=1, i=3506, loss=0.00148
# epoch=1, i=3507, loss=0.00395
# epoch=1, i=3508, loss=0.00053
# epoch=1, i=3509, loss=0.00056
# epoch=1, i=3510, loss=0.00017
# epoch=1, i=3511, loss=0.00013
# epoch=1, i=3512, loss=0.00027
# epoch=1, i=3513, loss=0.00398
# epoch=1, i=3514, loss=0.00000
# epoch=1, i=3515, loss=0.00036
# epoch=1, i=3516, loss=0.00272
# epoch=1, i=3517, loss=0.00023
# epoch=1, i=3518, loss=0.00010
# epoch=1, i=3519, loss=0.00001
# epoch=1, i=3520, loss=0.00043
# epoch=1, i=3521, loss=0.00075
# epoch=1, i=3522, loss=0.00009
# epoch=1, i=3523, loss=0.00035
# epoch=1, i=3524, loss=0.00178
# epoch=1, i=3525, loss=0.00000
# epoch=1, i=3526, loss=0.00049
# epoch=1, i=3527, loss=0.00339
# epoch=1, i=3528, loss=0.00001
# epoch=1, i=3529, loss=0.00002
# epoch=1, i=3530, loss=0.00003
# epoch=1, i=3531, loss=0.00003
# epoch=1, i=3532, loss=0.00004
# epoch=1, i=3533, loss=0.00000
# epoch=1, i=3534, loss=0.00037
# epoch=1, i=3535, loss=0.00193
# epoch=1, i=3536, loss=0.00032
# epoch=1, i=3537, loss=0.00003
# epoch=1, i=3538, loss=0.00076
# epoch=1, i=3539, loss=0.00002
# epoch=1, i=3540, loss=0.00181
# epoch=1, i=3541, loss=0.00068
# epoch=1, i=3542, loss=0.00031
# epoch=1, i=3543, loss=0.00009
# epoch=1, i=3544, loss=0.00031
# epoch=1, i=3545, loss=0.00003
# epoch=1, i=3546, loss=0.00198
# epoch=1, i=3547, loss=0.00011
# epoch=1, i=3548, loss=0.00000
# epoch=1, i=3549, loss=0.00185
# epoch=1, i=3550, loss=0.00036
# epoch=1, i=3551, loss=0.00050
# epoch=1, i=3552, loss=0.00281
# epoch=1, i=3553, loss=0.00055
# epoch=1, i=3554, loss=0.00035
# epoch=1, i=3555, loss=0.00019
# epoch=1, i=3556, loss=0.00056
# epoch=1, i=3557, loss=0.00034
# epoch=1, i=3558, loss=0.00004
# epoch=1, i=3559, loss=0.00072
# epoch=1, i=3560, loss=0.00000
# epoch=1, i=3561, loss=0.00026
# epoch=1, i=3562, loss=0.00001
# epoch=1, i=3563, loss=0.00055
# epoch=1, i=3564, loss=0.00034
# epoch=1, i=3565, loss=0.00008
# epoch=1, i=3566, loss=0.00239
# epoch=1, i=3567, loss=0.00064
# epoch=1, i=3568, loss=0.00018
# epoch=1, i=3569, loss=0.00499
# epoch=1, i=3570, loss=0.00025
# epoch=1, i=3571, loss=0.00006
# epoch=1, i=3572, loss=0.00060
# epoch=1, i=3573, loss=0.00053
# epoch=1, i=3574, loss=0.00060
# epoch=1, i=3575, loss=0.00044
# epoch=1, i=3576, loss=0.00023
# epoch=1, i=3577, loss=0.00099
# epoch=1, i=3578, loss=0.00006
# epoch=1, i=3579, loss=0.00002
# epoch=1, i=3580, loss=0.00000
# epoch=1, i=3581, loss=0.00148
# epoch=1, i=3582, loss=0.00154
# epoch=1, i=3583, loss=0.03203
# epoch=1, i=3584, loss=0.00258
# epoch=1, i=3585, loss=0.00087
# epoch=1, i=3586, loss=0.00239
# epoch=1, i=3587, loss=0.00005
# epoch=1, i=3588, loss=0.00177
# epoch=1, i=3589, loss=0.00288
# epoch=1, i=3590, loss=0.01996
# epoch=1, i=3591, loss=0.00007
# epoch=1, i=3592, loss=0.02203
# epoch=1, i=3593, loss=0.00228
# epoch=1, i=3594, loss=0.00132
# epoch=1, i=3595, loss=0.00036
# epoch=1, i=3596, loss=0.00446
# epoch=1, i=3597, loss=0.00107
# epoch=1, i=3598, loss=0.00018
# epoch=1, i=3599, loss=0.00641
# epoch=1, i=3600, loss=0.00062
# epoch=1, i=3601, loss=0.00024
# epoch=1, i=3602, loss=0.00028
# epoch=1, i=3603, loss=0.00317
# epoch=1, i=3604, loss=0.00543
# epoch=1, i=3605, loss=0.00399
# epoch=1, i=3606, loss=0.00065
# epoch=1, i=3607, loss=0.00221
# epoch=1, i=3608, loss=0.00036
# epoch=1, i=3609, loss=0.00077
# epoch=1, i=3610, loss=0.04280
# epoch=1, i=3611, loss=0.00124
# epoch=1, i=3612, loss=0.00004
# epoch=1, i=3613, loss=0.03096
# epoch=1, i=3614, loss=0.00671
# epoch=1, i=3615, loss=0.00149
# epoch=1, i=3616, loss=0.00166
# epoch=1, i=3617, loss=0.00378
# epoch=1, i=3618, loss=0.00645
# epoch=1, i=3619, loss=0.01349
# epoch=1, i=3620, loss=0.00000
# epoch=1, i=3621, loss=0.01075
# epoch=1, i=3622, loss=0.00010
# epoch=1, i=3623, loss=0.01070
# epoch=1, i=3624, loss=0.00062
# epoch=1, i=3625, loss=0.00392
# epoch=1, i=3626, loss=0.00066
# epoch=1, i=3627, loss=0.00037
# epoch=1, i=3628, loss=0.00748
# epoch=1, i=3629, loss=0.00654
# epoch=1, i=3630, loss=0.00018
# epoch=1, i=3631, loss=0.00483
# epoch=1, i=3632, loss=0.01317
# epoch=1, i=3633, loss=0.00113
# epoch=1, i=3634, loss=0.00040
# epoch=1, i=3635, loss=0.00194
# epoch=1, i=3636, loss=0.00070
# epoch=1, i=3637, loss=0.00142
# epoch=1, i=3638, loss=0.00359
# epoch=1, i=3639, loss=0.00222
# epoch=1, i=3640, loss=0.00996
# epoch=1, i=3641, loss=0.00342
# epoch=1, i=3642, loss=0.00212
# epoch=1, i=3643, loss=0.00078
# epoch=1, i=3644, loss=0.00251
# epoch=1, i=3645, loss=0.00382
# epoch=1, i=3646, loss=0.00892
# epoch=1, i=3647, loss=0.00086
# epoch=1, i=3648, loss=0.00699
# epoch=1, i=3649, loss=0.00312
# epoch=1, i=3650, loss=0.00060
# epoch=1, i=3651, loss=0.00128
# epoch=1, i=3652, loss=0.00064
# epoch=1, i=3653, loss=0.00420
# epoch=1, i=3654, loss=0.00463
# epoch=1, i=3655, loss=0.00011
# epoch=1, i=3656, loss=0.00824
# epoch=1, i=3657, loss=0.00195
# epoch=1, i=3658, loss=0.00049
# epoch=1, i=3659, loss=0.00007
# epoch=1, i=3660, loss=0.00348
# epoch=1, i=3661, loss=0.00013
# epoch=1, i=3662, loss=0.00018
# epoch=1, i=3663, loss=0.00120
# epoch=1, i=3664, loss=0.00416
# epoch=1, i=3665, loss=0.00543
# epoch=1, i=3666, loss=0.00005
# epoch=1, i=3667, loss=0.00120
# epoch=1, i=3668, loss=0.00048
# epoch=1, i=3669, loss=0.00180
# epoch=1, i=3670, loss=0.00247
# epoch=1, i=3671, loss=0.00002
# epoch=1, i=3672, loss=0.00122
# epoch=1, i=3673, loss=0.00179
# epoch=1, i=3674, loss=0.00184
# epoch=1, i=3675, loss=0.00016
# epoch=1, i=3676, loss=0.00047
# epoch=1, i=3677, loss=0.00064
# epoch=1, i=3678, loss=0.00041
# epoch=1, i=3679, loss=0.00214
# epoch=1, i=3680, loss=0.00106
# epoch=1, i=3681, loss=0.00141
# epoch=1, i=3682, loss=0.00357
# epoch=1, i=3683, loss=0.00000
# epoch=1, i=3684, loss=0.00027
# epoch=1, i=3685, loss=0.00116
# epoch=1, i=3686, loss=0.00074
# epoch=1, i=3687, loss=0.00572
# epoch=1, i=3688, loss=0.00016
# epoch=1, i=3689, loss=0.00001
# epoch=1, i=3690, loss=0.00006
# epoch=1, i=3691, loss=0.00208
# epoch=1, i=3692, loss=0.00151
# epoch=1, i=3693, loss=0.00007
# epoch=1, i=3694, loss=0.00023
# epoch=1, i=3695, loss=0.00131
# epoch=1, i=3696, loss=0.03274
# epoch=1, i=3697, loss=0.00176
# epoch=1, i=3698, loss=0.00743
# epoch=1, i=3699, loss=0.00091
# epoch=1, i=3700, loss=0.00004
# epoch=1, i=3701, loss=0.00000
# epoch=1, i=3702, loss=0.00356
# epoch=1, i=3703, loss=0.00197
# epoch=1, i=3704, loss=0.00000
# epoch=1, i=3705, loss=0.00007
# epoch=1, i=3706, loss=0.00004
# epoch=1, i=3707, loss=0.00424
# epoch=1, i=3708, loss=0.00119
# epoch=1, i=3709, loss=0.00049
# epoch=1, i=3710, loss=0.00037
# epoch=1, i=3711, loss=0.01941
# epoch=1, i=3712, loss=0.01415
# epoch=1, i=3713, loss=0.00062
# epoch=1, i=3714, loss=0.00247
# epoch=1, i=3715, loss=0.01023
# epoch=1, i=3716, loss=0.00000
# epoch=1, i=3717, loss=0.00093
# epoch=1, i=3718, loss=0.00678
# epoch=1, i=3719, loss=0.00105
# epoch=1, i=3720, loss=0.00492
# epoch=1, i=3721, loss=0.00217
# epoch=1, i=3722, loss=0.00002
# epoch=1, i=3723, loss=0.00609
# epoch=1, i=3724, loss=0.00475
# epoch=1, i=3725, loss=0.00692
# epoch=1, i=3726, loss=0.00053
# epoch=1, i=3727, loss=0.00149
# epoch=1, i=3728, loss=0.00513
# epoch=1, i=3729, loss=0.00045
# epoch=1, i=3730, loss=0.00001
# epoch=1, i=3731, loss=0.00501
# epoch=1, i=3732, loss=0.00227
# epoch=1, i=3733, loss=0.01211
# epoch=1, i=3734, loss=0.00003
# epoch=1, i=3735, loss=0.00014
# epoch=1, i=3736, loss=0.00199
# epoch=1, i=3737, loss=0.00005
# epoch=1, i=3738, loss=0.00154
# epoch=1, i=3739, loss=0.01195
# epoch=1, i=3740, loss=0.00045
# epoch=1, i=3741, loss=0.00138
# epoch=1, i=3742, loss=0.00359
# epoch=1, i=3743, loss=0.00099
# epoch=1, i=3744, loss=0.00167
# epoch=1, i=3745, loss=0.00178
# epoch=1, i=3746, loss=0.00543
# epoch=1, i=3747, loss=0.00067
# epoch=1, i=3748, loss=0.00568
# epoch=1, i=3749, loss=0.00118
# epoch=1, i=3750, loss=0.00296
# epoch=1, i=3751, loss=0.00135
# epoch=1, i=3752, loss=0.00015
# epoch=1, i=3753, loss=0.00076
# epoch=1, i=3754, loss=0.00314
# epoch=1, i=3755, loss=0.00004
# epoch=1, i=3756, loss=0.00283
# epoch=1, i=3757, loss=0.00734
# epoch=1, i=3758, loss=0.00076
# epoch=1, i=3759, loss=0.00257
# epoch=1, i=3760, loss=0.00001
# epoch=1, i=3761, loss=0.00317
# epoch=1, i=3762, loss=0.00243
# epoch=1, i=3763, loss=0.01574
# epoch=1, i=3764, loss=0.00149
# epoch=1, i=3765, loss=0.00003
# epoch=1, i=3766, loss=0.00069
# epoch=1, i=3767, loss=0.00126
# epoch=1, i=3768, loss=0.04704
# epoch=1, i=3769, loss=0.01442
# epoch=1, i=3770, loss=0.00465
# epoch=1, i=3771, loss=0.00611
# epoch=1, i=3772, loss=0.00689
# epoch=1, i=3773, loss=0.00154
# epoch=1, i=3774, loss=0.00003
# epoch=1, i=3775, loss=0.00042
# epoch=1, i=3776, loss=0.00123
# epoch=1, i=3777, loss=0.00528
# epoch=1, i=3778, loss=0.00442
# epoch=1, i=3779, loss=0.00001
# epoch=1, i=3780, loss=0.00239
# epoch=1, i=3781, loss=0.00004
# epoch=1, i=3782, loss=0.00031
# epoch=1, i=3783, loss=0.00524
# epoch=1, i=3784, loss=0.00011
# epoch=1, i=3785, loss=0.00035
# epoch=1, i=3786, loss=0.00137
# epoch=1, i=3787, loss=0.00027
# epoch=1, i=3788, loss=0.00162
# epoch=1, i=3789, loss=0.00008
# epoch=1, i=3790, loss=0.00206
# epoch=1, i=3791, loss=0.00331
# epoch=1, i=3792, loss=0.00063
# epoch=1, i=3793, loss=0.00057
# epoch=1, i=3794, loss=0.00005
# epoch=1, i=3795, loss=0.00969
# epoch=1, i=3796, loss=0.01710
# epoch=1, i=3797, loss=0.00215
# epoch=1, i=3798, loss=0.00003
# epoch=1, i=3799, loss=0.00429
# epoch=1, i=3800, loss=0.00072
# epoch=1, i=3801, loss=0.00012
# epoch=1, i=3802, loss=0.00063
# epoch=1, i=3803, loss=0.00005
# epoch=1, i=3804, loss=0.00006
# epoch=1, i=3805, loss=0.02560
# epoch=1, i=3806, loss=0.00040
# epoch=1, i=3807, loss=0.00363
# epoch=1, i=3808, loss=0.00186
# epoch=1, i=3809, loss=0.02127
# epoch=1, i=3810, loss=0.00239
# epoch=1, i=3811, loss=0.00460
# epoch=1, i=3812, loss=0.00011
# epoch=1, i=3813, loss=0.00001
# epoch=1, i=3814, loss=0.00008
# epoch=1, i=3815, loss=0.00418
# epoch=1, i=3816, loss=0.00002
# epoch=1, i=3817, loss=0.00000
# epoch=1, i=3818, loss=0.00349
# epoch=1, i=3819, loss=0.00063
# epoch=1, i=3820, loss=0.00080
# epoch=1, i=3821, loss=0.00379
# epoch=1, i=3822, loss=0.00045
# epoch=1, i=3823, loss=0.00690
# epoch=1, i=3824, loss=0.00005
# epoch=1, i=3825, loss=0.00009
# epoch=1, i=3826, loss=0.00064
# epoch=1, i=3827, loss=0.00613
# epoch=1, i=3828, loss=0.00087
# epoch=1, i=3829, loss=0.00398
# epoch=1, i=3830, loss=0.00037
# epoch=1, i=3831, loss=0.00488
# epoch=1, i=3832, loss=0.00045
# epoch=1, i=3833, loss=0.00241
# epoch=1, i=3834, loss=0.00057
# epoch=1, i=3835, loss=0.00320
# epoch=1, i=3836, loss=0.00012
# epoch=1, i=3837, loss=0.00213
# epoch=1, i=3838, loss=0.00021
# epoch=1, i=3839, loss=0.00515
# epoch=1, i=3840, loss=0.00289
# epoch=1, i=3841, loss=0.00042
# epoch=1, i=3842, loss=0.00525
# epoch=1, i=3843, loss=0.00000
# epoch=1, i=3844, loss=0.00258
# epoch=1, i=3845, loss=0.00012
# epoch=1, i=3846, loss=0.00607
# epoch=1, i=3847, loss=0.00238
# epoch=1, i=3848, loss=0.00015
# epoch=1, i=3849, loss=0.00001
# epoch=1, i=3850, loss=0.00024
# epoch=1, i=3851, loss=0.00174
# epoch=1, i=3852, loss=0.00003
# epoch=1, i=3853, loss=0.00280
# epoch=1, i=3854, loss=0.00026
# epoch=1, i=3855, loss=0.00001
# epoch=1, i=3856, loss=0.01126
# epoch=1, i=3857, loss=0.00786
# epoch=1, i=3858, loss=0.00450
# epoch=1, i=3859, loss=0.00327
# epoch=1, i=3860, loss=0.00561
# epoch=1, i=3861, loss=0.01422
# epoch=1, i=3862, loss=0.00064
# epoch=1, i=3863, loss=0.00035
# epoch=1, i=3864, loss=0.00284
# epoch=1, i=3865, loss=0.00292
# epoch=1, i=3866, loss=0.02005
# epoch=1, i=3867, loss=0.00020
# epoch=1, i=3868, loss=0.00041
# epoch=1, i=3869, loss=0.00149
# epoch=1, i=3870, loss=0.00073
# epoch=1, i=3871, loss=0.00435
# epoch=1, i=3872, loss=0.00115
# epoch=1, i=3873, loss=0.00004
# epoch=1, i=3874, loss=0.00208
# epoch=1, i=3875, loss=0.05020
# epoch=1, i=3876, loss=0.00504
# epoch=1, i=3877, loss=0.00009
# epoch=1, i=3878, loss=0.00324
# epoch=1, i=3879, loss=0.00008
# epoch=1, i=3880, loss=0.00000
# epoch=1, i=3881, loss=0.00370
# epoch=1, i=3882, loss=0.00056
# epoch=1, i=3883, loss=0.00336
# epoch=1, i=3884, loss=0.00623
# epoch=1, i=3885, loss=0.00006
# epoch=1, i=3886, loss=0.00173
# epoch=1, i=3887, loss=0.01077
# epoch=1, i=3888, loss=0.00173
# epoch=1, i=3889, loss=0.00565
# epoch=1, i=3890, loss=0.00138
# epoch=1, i=3891, loss=0.00687
# epoch=1, i=3892, loss=0.00057
# epoch=1, i=3893, loss=0.00904
# epoch=1, i=3894, loss=0.00002
# epoch=1, i=3895, loss=0.00072
# epoch=1, i=3896, loss=0.00281
# epoch=1, i=3897, loss=0.00027
# epoch=1, i=3898, loss=0.00005
# epoch=1, i=3899, loss=0.00095
# epoch=1, i=3900, loss=0.00220
# epoch=1, i=3901, loss=0.00942
# epoch=1, i=3902, loss=0.00007
# epoch=1, i=3903, loss=0.00023
# epoch=1, i=3904, loss=0.00490
# epoch=1, i=3905, loss=0.00026
# epoch=1, i=3906, loss=0.00033
# epoch=1, i=3907, loss=0.00312
# epoch=1, i=3908, loss=0.01159
# epoch=1, i=3909, loss=0.00054
# epoch=1, i=3910, loss=0.00592
# epoch=1, i=3911, loss=0.00103
# epoch=1, i=3912, loss=0.00345
# epoch=1, i=3913, loss=0.00000
# epoch=1, i=3914, loss=0.00168
# epoch=1, i=3915, loss=0.00016
# epoch=1, i=3916, loss=0.00255
# epoch=1, i=3917, loss=0.00710
# epoch=1, i=3918, loss=0.00057
# epoch=1, i=3919, loss=0.00013
# epoch=1, i=3920, loss=0.04001
# epoch=1, i=3921, loss=0.00543
# epoch=1, i=3922, loss=0.00772
# epoch=1, i=3923, loss=0.00002
# epoch=1, i=3924, loss=0.00061
# epoch=1, i=3925, loss=0.01816
# epoch=1, i=3926, loss=0.00004
# epoch=1, i=3927, loss=0.00035
# epoch=1, i=3928, loss=0.01634
# epoch=1, i=3929, loss=0.00591
# epoch=1, i=3930, loss=0.00243
# epoch=1, i=3931, loss=0.00138
# epoch=1, i=3932, loss=0.00020
# epoch=1, i=3933, loss=0.01555
# epoch=1, i=3934, loss=0.02182
# epoch=1, i=3935, loss=0.00703
# epoch=1, i=3936, loss=0.01162
# epoch=1, i=3937, loss=0.00143
# epoch=1, i=3938, loss=0.00070
# epoch=1, i=3939, loss=0.00009
# epoch=1, i=3940, loss=0.03716
# epoch=1, i=3941, loss=0.00298
# epoch=1, i=3942, loss=0.00367
# epoch=1, i=3943, loss=0.00016
# epoch=1, i=3944, loss=0.01919
# epoch=1, i=3945, loss=0.00143
# epoch=1, i=3946, loss=0.00029
# epoch=1, i=3947, loss=0.00125
# epoch=1, i=3948, loss=0.00198
# epoch=1, i=3949, loss=0.02370
# epoch=1, i=3950, loss=0.00006
# epoch=1, i=3951, loss=0.00000
# epoch=1, i=3952, loss=0.00250
# epoch=1, i=3953, loss=0.00050
# epoch=1, i=3954, loss=0.00008
# epoch=1, i=3955, loss=0.00256
# epoch=1, i=3956, loss=0.00373
# epoch=1, i=3957, loss=0.00002
# epoch=1, i=3958, loss=0.00018
# epoch=1, i=3959, loss=0.00246
# epoch=1, i=3960, loss=0.00186
# epoch=1, i=3961, loss=0.00112
# epoch=1, i=3962, loss=0.00100
# epoch=1, i=3963, loss=0.00000
# epoch=1, i=3964, loss=0.00073
# epoch=1, i=3965, loss=0.01017
# epoch=1, i=3966, loss=0.00011
# epoch=1, i=3967, loss=0.00054
# epoch=1, i=3968, loss=0.00281
# epoch=1, i=3969, loss=0.00139
# epoch=1, i=3970, loss=0.00082
# epoch=1, i=3971, loss=0.00031
# epoch=1, i=3972, loss=0.00005
# epoch=1, i=3973, loss=0.00098
# epoch=1, i=3974, loss=0.00233
# epoch=1, i=3975, loss=0.00003
# epoch=1, i=3976, loss=0.00196
# epoch=1, i=3977, loss=0.01744
# epoch=1, i=3978, loss=0.01077
# epoch=1, i=3979, loss=0.00418
# epoch=1, i=3980, loss=0.00006
# epoch=1, i=3981, loss=0.00038
# epoch=1, i=3982, loss=0.00298
# epoch=1, i=3983, loss=0.00000
# epoch=1, i=3984, loss=0.00223
# epoch=1, i=3985, loss=0.00605
# epoch=1, i=3986, loss=0.00187
# epoch=1, i=3987, loss=0.00711
# epoch=1, i=3988, loss=0.00002
# epoch=1, i=3989, loss=0.00118
# epoch=1, i=3990, loss=0.00417
# epoch=1, i=3991, loss=0.00050
# epoch=1, i=3992, loss=0.00628
# epoch=1, i=3993, loss=0.00022
# epoch=1, i=3994, loss=0.00398
# epoch=1, i=3995, loss=0.00008
# epoch=1, i=3996, loss=0.00180
# epoch=1, i=3997, loss=0.00628
# epoch=1, i=3998, loss=0.00090
# epoch=1, i=3999, loss=0.00149
# epoch=1, i=4000, loss=0.00056
# epoch=1, i=4001, loss=0.00739
# epoch=1, i=4002, loss=0.00587
# epoch=1, i=4003, loss=0.00030
# epoch=1, i=4004, loss=0.00000
# epoch=1, i=4005, loss=0.00057
# epoch=1, i=4006, loss=0.00803
# epoch=1, i=4007, loss=0.00010
# epoch=1, i=4008, loss=0.00009
# epoch=1, i=4009, loss=0.00007

# %%
model.eval()
# Out:
# TimeEmbeddingTransformer(
#   (time_embedding): TimeVector()
#   (attn_layer1): TransformerEncoder(
#     (attn_multi): MultiAttention(
#       (linear): Linear(in_features=768, out_features=7, bias=True)
#     )
#     (attn_dropout): Dropout(p=0.1, inplace=False)
#     (attn_normalize): LayerNorm((32, 7), eps=1e-06, elementwise_affine=True)
#     (ff_conv1d_1): Conv1d(32, 64, kernel_size=(1,), stride=(1,))
#     (ff_conv1d_2): Conv1d(64, 32, kernel_size=(1,), stride=(1,))
#     (ff_dropout): Dropout(p=0.1, inplace=False)
#     (ff_normalize): LayerNorm((32, 7), eps=1e-06, elementwise_affine=True)
#   )
#   (attn_layer2): TransformerEncoder(
#     (attn_multi): MultiAttention(
#       (linear): Linear(in_features=768, out_features=7, bias=True)
#     )
#     (attn_dropout): Dropout(p=0.1, inplace=False)
#     (attn_normalize): LayerNorm((32, 7), eps=1e-06, elementwise_affine=True)
#     (ff_conv1d_1): Conv1d(32, 64, kernel_size=(1,), stride=(1,))
#     (ff_conv1d_2): Conv1d(64, 32, kernel_size=(1,), stride=(1,))
#     (ff_dropout): Dropout(p=0.1, inplace=False)
#     (ff_normalize): LayerNorm((32, 7), eps=1e-06, elementwise_affine=True)
#   )
#   (attn_layer3): TransformerEncoder(
#     (attn_multi): MultiAttention(
#       (linear): Linear(in_features=768, out_features=7, bias=True)
#     )
#     (attn_dropout): Dropout(p=0.1, inplace=False)
#     (attn_normalize): LayerNorm((32, 7), eps=1e-06, elementwise_affine=True)
#     (ff_conv1d_1): Conv1d(32, 64, kernel_size=(1,), stride=(1,))
#     (ff_conv1d_2): Conv1d(64, 32, kernel_size=(1,), stride=(1,))
#     (ff_dropout): Dropout(p=0.1, inplace=False)
#     (ff_normalize): LayerNorm((32, 7), eps=1e-06, elementwise_affine=True)
#   )
#   (dropout1): Dropout(p=0.1, inplace=False)
#   (linear1): Linear(in_features=32, out_features=16, bias=True)
#   (dropout2): Dropout(p=0.1, inplace=False)
#   (linear2): Linear(in_features=16, out_features=1, bias=True)
# )

# %%
y_val_pred = []
for data in X_val:
    y_val_pred.append(model(torch.tensor(data)).detach().numpy()[0])

# %%
sns.lineplot(y_val_pred)
# Out:
# <Axes: >

# %%
X_train[0].shape
# Out:
# (32, 5)
